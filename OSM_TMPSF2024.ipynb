# %%
import os
import re
import xarray as xr
import netCDF4
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import hvplot.pandas
import hvplot.dask  # noqa
import dask
from scipy import stats
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d3de9d7d-4672-44a9-ab5d-070f8508bd6e'>
#   <div id="cbd8b0db-2d56-4cf6-a0b0-b4aed705c650" data-root-id="d3de9d7d-4672-44a9-ab5d-070f8508bd6e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # Build TMPSF DataSet

# %%
TMPSF1 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0001_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20140929T190312-20141125T235952.nc'; 
TMPSF2 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0001_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20160531T000003.071069-20170724T235956.777524.nc';
#TMPSF3 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0001_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20170725T000001.776108-20170813T232226.349596.nc';
#Note, TMPSF3 file had errors last I checked, so it is not included.
TMPSF4 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20170815T003130.804600-20190115T235955.435925.nc';
TMPSF5 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20190116T000005.434363-20200626T235957.130662.nc';
TMPSF6 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20200627T000007.128494-20211130T235953.099290.nc';
TMPSF7 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20211201T000003.098892-20220913T021116.589039.nc';
TMPSF8 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20220913T021116.589039-20220923T225926.025380.nc';
TMPSF9 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20220923T225926.025380-20220925T165205.935817.nc';

# %%
ds = xr.open_dataset(TMPSF1)
    #define dataset
ds = ds.swap_dims({'obs': 'time'}) 
    #swapping dimensions
ds = ds.chunk({'time': 1000})
    #chunk the time
ds = ds.sortby('time')

ds2 = xr.open_dataset(TMPSF2)
ds2 = ds2.swap_dims({'obs': 'time'}) 
ds2 = ds2.chunk({'time': 1000})
ds2 = ds2.sortby('time')

ds4 = xr.open_dataset(TMPSF4)
ds4 = ds4.swap_dims({'obs': 'time'}) 
ds4 = ds4.chunk({'time': 1000})
ds4 = ds4.sortby('time')

ds5 = xr.open_dataset(TMPSF5)
ds5 = ds5.swap_dims({'obs': 'time'}) 
ds5 = ds5.chunk({'time': 1000})
ds5 = ds5.sortby('time')

ds6 = xr.open_dataset(TMPSF6)
ds6 = ds6.swap_dims({'obs': 'time'}) 
ds6 = ds6.chunk({'time': 1000})
ds6 = ds6.sortby('time')

ds7 = xr.open_dataset(TMPSF7)
ds7 = ds7.swap_dims({'obs': 'time'}) 
ds7 = ds7.chunk({'time': 1000})
ds7 = ds7.sortby('time')

ds8 = xr.open_dataset(TMPSF8)
ds8 = ds8.swap_dims({'obs': 'time'}) 
ds8 = ds8.chunk({'time': 1000})
ds8 = ds8.sortby('time')

ds9 = xr.open_dataset(TMPSF9)
ds9 = ds9.swap_dims({'obs': 'time'}) 
ds9 = ds9.chunk({'time': 1000})
ds9 = ds9.sortby('time')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/ooi2/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/.conda/envs/ooi2/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# ...

# %%
combined_dataset=ds
combined_dataset
# Out:
# <xarray.Dataset> Size: 171MB
# Dimensions:                        (time: 454366)
# Coordinates:
#     obs                            (time) int32 2MB dask.array<chunksize=(1000,), meta=np.ndarray>
#   * time                           (time) datetime64[ns] 4MB 2014-09-29T19:03...
# Data variables: (12/131)
#     temperature20_qartod_executed  (time) <U1 2MB dask.array<chunksize=(1000,), meta=np.ndarray>
#     temperature19_qartod_results   (time) uint8 454kB dask.array<chunksize=(1000,), meta=np.ndarray>
#     temperature03                  (time) float32 2MB dask.array<chunksize=(1000,), meta=np.ndarray>
#     temperature02                  (time) float32 2MB dask.array<chunksize=(1000,), meta=np.ndarray>
#     temperature01                  (time) float32 2MB dask.array<chunksize=(1000,), meta=np.ndarray>
#     temperature07                  (time) float32 2MB dask.array<chunksize=(1000,), meta=np.ndarray>
#     ...                             ...
# ...

# %%
#combined_dataset = xr.concat([ds, ds2, ds4, ds5, ds6, ds7, ds8, ds9], dim='time')

# %%
full_tmpsf=combined_dataset[['time', 'temperature01', 'temperature02', 'temperature03','temperature04','temperature05','temperature06','temperature07','temperature08','temperature09','temperature10','temperature11','temperature12','temperature13','temperature14','temperature15','temperature02','temperature16','temperature17','temperature18','temperature19','temperature20','temperature21','temperature22','temperature23','temperature24']].to_pandas()
full_tmpsf.tail(5)
# Out:
#                      temperature01  temperature02  temperature03  \
# time
# 2014-11-25 23:59:12         2.7868      21.897100         2.9836
# 2014-11-25 23:59:22         2.7693      21.898800         2.9610
# 2014-11-25 23:59:32         2.7495      21.902201         2.9430
# 2014-11-25 23:59:42         2.7297      21.970900         2.9264
# 2014-11-25 23:59:52         2.7148      22.053200         2.9097
#
#                      temperature04  temperature05  temperature06  \
# time
# 2014-11-25 23:59:12         2.8185         5.6265         2.8242
# 2014-11-25 23:59:22         2.8193         5.6331         2.8411
# 2014-11-25 23:59:32         2.8243         5.6361         2.8517
# 2014-11-25 23:59:42         2.8293         5.6422         2.8507
# 2014-11-25 23:59:52         2.8406         5.6507         2.8546
#
#                      temperature07  temperature08  temperature09  \
# time
# 2014-11-25 23:59:12         3.5924         5.2560         3.3501
# ...

# %%
full_tmpsf.rename(columns={'temperature01':'t01','temperature02':'t02', 'temperature03':'t03'
                         ,'temperature04':'t04','temperature05':'t05','temperature06':'t06'
                         ,'temperature07':'t07','temperature08':'t08','temperature09':'t09'
                         ,'temperature10':'t10','temperature11':'t11','temperature12':'t12'
                         ,'temperature13':'t13','temperature14':'t14','temperature15':'t15'
                         ,'temperature16':'t16','temperature17':'t17','temperature18':'t18'
                         ,'temperature19':'t19','temperature20':'t20','temperature21':'t21'
                         ,'temperature22':'t22','temperature23':'t23','temperature24':'t24'}, inplace=True)
full_tmpsf.index=pd.to_datetime(full_tmpsf.index)
full_tmpsf = full_tmpsf.drop_duplicates(keep='first', inplace=False, ignore_index=False)
full_tmpsf['tl1'] = full_tmpsf[['t01', 't03', 't04', 't05', 't07']].mean(axis=1)
full_tmpsf['tl2'] = full_tmpsf[['t08', 't09', 't10', 't11', 't12', 't13', 't14']].mean(axis=1)
full_tmpsf['tl3'] = full_tmpsf[['t15', 't16', 't17', 't18', 't19', 't20', 't21']].mean(axis=1)
full_tmpsf['tl4'] = full_tmpsf[['t22', 't23', 't24']].mean(axis=1)
#full_tmpsf.drop(full_tmpsf.iloc[:, 0:25], inplace=True, axis=1)

full_tmpsf.head(5)
# Out:
#                         t01      t02     t03     t04     t05     t06     t07  \
# time
# 2014-09-29 19:03:12  4.1971  11.8625  4.7459  3.5317  4.6637  2.8325  3.8759
# 2014-09-29 19:03:22  4.2239  11.7928  4.8289  3.5500  4.7555  2.8303  3.9543
# 2014-09-29 19:03:32  4.2396  11.6364  4.9004  3.5744  4.8480  2.8142  4.0029
# 2014-09-29 19:03:42  4.2517  11.6801  4.9385  3.5962  4.8879  2.8018  4.0084
# 2014-09-29 19:03:52  4.2447  11.8516  4.8840  3.6196  4.8903  2.7826  3.9798
#
#                         t08     t09     t10  ...     t20     t21     t22  \
# time                                         ...
# 2014-09-29 19:03:12  3.5762  2.7715  3.2514  ...  2.5110  2.6266  2.4860
# 2014-09-29 19:03:22  3.5551  2.7659  3.2902  ...  2.5065  2.6178  2.4823
# 2014-09-29 19:03:32  3.5870  2.7521  3.3318  ...  2.5010  2.6137  2.4825
# 2014-09-29 19:03:42  3.5822  2.7732  3.3944  ...  2.4999  2.6231  2.4769
# 2014-09-29 19:03:52  3.6109  2.7805  3.4542  ...  2.4959  2.6279  2.4749
#
# ...

# %%
df_tmpsf_ave = full_tmpsf.resample('d').mean()
df_tmpsf_ave.tail()
# Out:
#                  t01        t02       t03       t04       t05       t06  \
# time
# 2014-11-21  3.258580  19.675644  3.406706  3.276741  5.065306  2.797983
# 2014-11-22  2.949707  20.413202  2.972578  3.140280  3.882782  2.886856
# 2014-11-23  3.061387  20.643499  3.079684  3.129770  4.132244  2.844556
# 2014-11-24  3.002082  21.006624  3.000816  3.126767  4.025038  2.815562
# 2014-11-25  2.999777  21.205688  2.995493  3.106681  4.040669  2.861414
#
#                  t07       t08       t09       t10  ...       t20       t21  \
# time                                                ...
# 2014-11-21  3.490406  3.701322  2.921686  3.304590  ...  2.646814  2.896591
# 2014-11-22  3.351916  3.254943  2.843414  2.936433  ...  2.629048  2.812821
# 2014-11-23  3.447382  3.343183  2.844889  3.085641  ...  2.649713  2.884249
# 2014-11-24  3.394172  3.285632  2.786414  2.964121  ...  2.629536  2.841475
# 2014-11-25  3.412836  3.382625  2.781873  2.957164  ...  2.617071  2.838648
#
# ...

# %%
#df_tmpsf_ave.to_csv('/home/jovyan/data/axial/axial_tmpsf/axial_tmpsf.csv')

# %%
#df_dask = dask.dataframe.from_pandas(df_resamp, npartitions=10)
#df_dask

# %%
#df_dask.hvplot.step(x='time', y=['tl1', 'tl2', 'tl3', 'tl4'])

# %%
#first jump 1/25/2017
#end jump 07/24/2017
