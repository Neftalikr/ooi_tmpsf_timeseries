# %%
# !pip install xarray netCDF4
# Out:
# ...
#   Using cached xarray-2025.6.1-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached netCDF4-1.7.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# ...
#   Using cached cftime-1.6.4.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# ...
# Using cached xarray-2025.6.1-py3-none-any.whl (1.3 MB)
# Using cached netCDF4-1.7.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
# Using cached cftime-1.6.4.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
# ...

# %%
# !pip install hvplot
# Out:
# ...
#   Using cached hvplot-0.11.3-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached colorcet-3.1.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached holoviews-1.20.2-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached panel-1.7.1-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached param-2.2.1-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached pyviz_comms-3.0.6-py3-none-any.whl.metadata (7.7 kB)
# ...
#   Using cached linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached markdown-3.8.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# ...
# Using cached hvplot-0.11.3-py3-none-any.whl (170 kB)
# Using cached colorcet-3.1.0-py3-none-any.whl (260 kB)
# Using cached holoviews-1.20.2-py3-none-any.whl (5.0 MB)
# Using cached panel-1.7.1-py3-none-any.whl (29.5 MB)
# Using cached param-2.2.1-py3-none-any.whl (119 kB)
# Using cached pyviz_comms-3.0.6-py3-none-any.whl (84 kB)
# ...

# %%
import os
import re
import xarray as xr
import netCDF4
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import hvplot.pandas
import hvplot.dask # noqa
import dask
from scipy import stats
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
#/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='42043786-0bb6-4a5c-a2d3-03156712a1cd'>
#   <div id="b645c17c-720f-4bae-a597-053858cfb2de" data-root-id="42043786-0bb6-4a5c-a2d3-03156712a1cd" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
TMPSF369 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231001T073341.326208-20231002T082851.270141.nc';
TMPSF370 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231002T082851.270141-20231003T083411.215692.nc';
TMPSF371 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231003T083411.215692-20231004T081321.161919.nc';
TMPSF372 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231004T081321.161919-20231005T081231.113970.nc';
TMPSF373 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231005T081231.113970-20231006T074641.059457.nc';
TMPSF374 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231006T074641.059457-20231007T074701.009452.nc';
TMPSF375 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231007T074701.009452-20231008T081840.957887.nc';
TMPSF376 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231008T081840.957887-20231009T082240.904519.nc';
TMPSF377 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231009T082240.904519-20231010T081350.854690.nc';
TMPSF378 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231010T081350.854690-20231011T081900.803957.nc';
TMPSF379 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231011T081900.803957-20231012T083730.753307.nc';
TMPSF380 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231012T083730.753307-20231013T090230.700609.nc';
TMPSF381 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231013T090230.700609-20231014T084240.651040.nc';
TMPSF382 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231014T084240.651040-20231015T084400.601829.nc';
TMPSF383 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231015T084400.601829-20231016T084410.550883.nc';
TMPSF384 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231016T084410.550883-20231017T084700.492873.nc';
TMPSF385 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231017T084700.492873-20231018T084810.446628.nc';
TMPSF386 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231018T084810.446628-20231019T085120.391698.nc';
TMPSF387 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20231019T085120.391698-20231020T085510.339650.nc';
TMPSF388 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_
='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250203T091713.615824-20250204T091723.563262.nc';
TMPSF830 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250204T091723.563262-20250205T092053.510270.nc';
TMPSF831 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250205T092053.510270-20250206T092103.445518.nc';
TMPSF832 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250206T092103.445518-20250207T092003.404941.nc';
TMPSF833 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250207T092003.404941-20250208T092123.353408.nc';
TMPSF834 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250208T092123.353408-20250209T092143.305822.nc';
TMPSF835 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250209T092143.305822-20250210T092143.244313.nc';
TMPSF836 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250210T092143.244313-20250211T093543.200604.nc';
TMPSF837 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250211T093543.200604-20250212T092953.150323.nc';
TMPSF838 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250212T092953.150323-20250213T092943.107964.nc';
TMPSF839 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250213T092943.107964-20250214T093453.059164.nc';
TMPSF840 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250214T093453.059164-20250215T093532.999320.nc';
TMPSF841 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250215T093532.999320-20250216T093712.951252.nc';
TMPSF842 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250216T093712.951252-20250217T093942.891970.nc';
TMPSF843 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250217T093942.891970-20250218T094102.843495.nc';
TMPSF844 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250218T094102.843495-20250219T094042.804188.nc';
TMPSF845 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250219T094042.804188-20250220T115612.741210.nc';
TMPSF846 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250220T115612.741210-20250221T093642.713427.nc';
TMPSF847 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250221T093642.713427-20250222T093712.656396.nc';
TMPSF848 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250222T093712.656396-20250223T093852.602124.nc';
TMPSF849 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250223T093852.602124-20250224T093812.543163.nc';
TMPSF850 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250224T093812.543163-20250225T094132.478229.nc';
TMPSF851 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250225T094132.478229-20250226T094052.420726.nc';
TMPSF852 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250226T094052.420726-20250227T093942.376860.nc';
TMPSF853 ='/home/jovyan/ooi/kdata/RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample/deployment0002_RS03ASHS-MJ03B-07-TMPSFA301-streamed-tmpsf_sample_20250227T093942.376860-20250228T093832.319009.nc';

# %%
ds369 = xr.open_dataset(TMPSF369)
ds369 = ds369.swap_dims({'obs': 'time'})
ds369 = ds369.chunk({'time': 1000})
ds369 = ds369.sortby('time')

ds370 = xr.open_dataset(TMPSF370)
ds370 = ds370.swap_dims({'obs': 'time'})
ds370 = ds370.chunk({'time': 1000})
ds370 = ds370.sortby('time')

ds371 = xr.open_dataset(TMPSF371)
ds371 = ds371.swap_dims({'obs': 'time'})
ds371 = ds371.chunk({'time': 1000})
ds371 = ds371.sortby('time')

ds372 = xr.open_dataset(TMPSF372)
ds372 = ds372.swap_dims({'obs': 'time'})
ds372 = ds372.chunk({'time': 1000})
ds372 = ds372.sortby('time')

ds373 = xr.open_dataset(TMPSF373)
ds373 = ds373.swap_dims({'obs': 'time'})
ds373 = ds373.chunk({'time': 1000})
ds373 = ds373.sortby('time')

ds374 = xr.open_dataset(TMPSF374)
ds374 = ds374.swap_dims({'obs': 'time'})
ds374 = ds374.chunk({'time': 1000})
ds374 = ds374.sortby('time')

ds375 = xr.open_dataset(TMPSF375)
ds375 = ds375.swap_dims({'obs': 'time'})
ds375 = ds375.chunk({'time': 1000})
ds375 = ds375.sortby('time')

ds376 = xr.open_dataset(TMPSF376)
ds376 = ds376.swap_dims({'obs': 'time'})
ds376 = ds376.chunk({'time': 1000})
ds376 = ds376.sortby('time')

ds377 = xr.open_dataset(TMPSF377)
ds377 = ds377.swap_dims({'obs': 'time'})
ds377 = ds377.chunk({'time': 1000})
ds377 = ds377.sortby('time')

ds378 = xr.open_dataset(TMPSF378)
ds378 = ds378.swap_dims({'obs': 'time'})
ds378 = ds378.chunk({'time': 1000})
ds378 = ds378.sortby('time')

ds379 = xr.open_dataset(TMPSF379)
ds379 = ds379.swap_dims({'obs': 'time'})
ds379 = ds379.chunk({'time': 1000})
ds379 = ds379.sortby('time')

ds380 = xr.open_dataset(TMPSF380)
ds380 = ds380.swap_dims({'obs': 'time'})
ds380 = ds380.chunk({'time': 1000})
ds380 = ds380.sortby('time')

ds381 = xr.open_dataset(TMPSF381)
ds381 = ds381.swap_dims({'obs': 'time'})
ds381 = ds381.chunk({'time': 1000})
ds381 = ds381.sortby('time')

ds382 = xr.open_dataset(TMPSF382)
ds382 = ds382.swap_dims({'obs': 'time'})
ds382 = ds382.chunk({'time': 1000})
ds382 = ds382.sortby('time')

ds383 = xr.open_dataset(TMPSF383)
ds383 = ds383.swap_dims({'obs': 'time'})
ds383 = ds383.chunk({'time': 1000})
ds383 = ds383.sortby('time')

ds384 = xr.open_dataset(TMPSF384)
ds384 = ds384.swap_dims({'obs': 'time'})
ds384 = ds384.chunk({'time': 1000})
ds384 = ds384.sortby('time')

ds385 = xr.open_dataset(TMPSF385)
ds385 = ds385.swap_dims({'obs': 'time'})
ds385 = ds385.chunk({'time': 1000})
ds385 = ds385.sortby('time')

ds386 = xr.open_dataset(TMPSF386)
ds386 = ds386.swap_dims({'obs': 'time'})
ds386 = ds386.chunk({'time': 1000})
ds386 = ds386.sortby('time')

ds387 = xr.open_dataset(TMPSF387)
ds387 = ds387.swap_dims({'obs': 'time'})
ds387 = ds387.chunk({'time': 1000})
ds387 = ds387.sortby('time')

ds388 = xr.open_dataset(TMPSF388)
ds388 = ds388.swap_dims({'obs': 'time'})
ds388 = ds388.chunk({'time': 1000})
ds388 = ds388.sortby('time')

ds389 = xr.open_dataset(TMPSF389)
ds389 = ds389.swap_dims({'obs': 'time'})
ds389 = ds389.chunk({'time': 1000})
ds389 = ds389.sortby('time')

ds390 = xr.open_dataset(TMPSF390)
ds390 = ds390.swap_dims({'obs': 'time'})
ds390 = ds390.chunk({'time': 1000})
ds390 = ds390.sortby('time')

ds391 = xr.open_dataset(TMPSF391)
ds391 = ds391.swap_dims({'obs': 'time'})
ds391 = ds391.chunk({'time': 1000})
ds391 = ds391.sortby('time')

ds392 = xr.open_dataset(TMPSF392)
ds392 = ds392.swap_dims({'obs': 'time'})
ds392 = ds392.chunk({'time': 1000})
ds392 = ds392.sortby('time')

ds393 = xr.open_dataset(TMPSF393)
ds393 = ds393.swap_dims({'obs': 'time'})
ds393 = ds393.chunk({'time': 1000})
ds393 = ds393.sortby('time')

ds394 = xr.open_dataset(TMPSF394)
ds394 = ds394.swap_dims({'obs': 'time'})
ds394 = ds394.chunk({'time': 1000})
ds394 = ds394.sortby('time')

ds395 = xr.open_dataset(TMPSF395)
ds395 = ds395.swap_dims({'obs': 'time'})
ds395 = ds395.chunk({'time': 1000})
ds395 = ds395.sortby('time')

ds396 = xr.open_dataset(TMPSF396)
ds396 = ds396.swap_dims({'obs': 'time'})
ds396 = ds396.chunk({'time': 1000})
ds396 = ds396.sortby('time')

ds397 = xr.open_dataset(TMPSF397)
ds397 = ds397.swap_dims({'obs': 'time'})
ds397 = ds397.chunk({'time': 1000})
ds397 = ds397.sortby('time')

ds398 = xr.open_dataset(TMPSF398)
ds398 = ds398.swap_dims({'obs': 'time'})
ds398 = ds398.chunk({'time': 1000})
ds398 = ds398.sortby('time')

ds399 = xr.open_dataset(TMPSF399)
ds399 = ds399.swap_dims({'obs': 'time'})
ds399 = ds399.chunk({'time': 1000})
ds399 = ds399.sortby('time')

ds400 = xr.open_dataset(TMPSF400)
ds400 = ds400.swap_dims({'obs': 'time'})
ds400 = ds400.chunk({'time': 1000})
ds400 = ds400.sortby('time')

ds401 = xr.open_dataset(TMPSF401)
ds401 = ds401.swap_dims({'obs': 'time'})
ds401 = ds401.chunk({'time': 1000})
ds401 = ds401.sortby('time')

ds402 = xr.open_dataset(TMPSF402)
ds402 = ds402.swap_dims({'obs': 'time'})
ds402 = ds402.chunk({'time': 1000})
ds402 = ds402.sortby('time')

ds403 = xr.open_dataset(TMPSF403)
ds403 = ds403.swap_dims({'obs': 'time'})
ds403 = ds403.chunk({'time': 1000})
ds403 = ds403.sortby('time')

ds404 = xr.open_dataset(TMPSF404)
ds404 = ds404.swap_dims({'obs': 'time'})
ds404 = ds404.chunk({'time': 1000})
ds404 = ds404.sortby('time')

ds405 = xr.open_dataset(TMPSF405)
ds405 = ds405.swap_dims({'obs': 'time'})
ds405 = ds405.chunk({'time': 1000})
ds405 = ds405.sortby('time')

ds406 = xr.open_dataset(TMPSF406)
ds406 = ds406.swap_dims({'obs': 'time'})
ds406 = ds406.chunk({'time': 1000})
ds406 = ds406.sortby('time')

ds407 = xr.open_dataset(TMPSF407)
ds407 = ds407.swap_dims({'obs': 'time'})
ds407 = ds407.chunk({'time': 1000})
ds407 = ds407.sortby('time')

ds408 = xr.open_dataset(TMPSF408)
ds408 = ds408.swap_dims({'obs': 'time'})
ds408 = ds408.chunk({'time': 1000})
ds408 = ds408.sortby('time')

ds409 = xr.open_dataset(TMPSF409)
ds409 = ds409.swap_dims({'obs': 'time'})
ds409 = ds409.chunk({'time': 1000})
ds409 = ds409.sortby('time')

ds410 = xr.open_dataset(TMPSF410)
ds410 = ds410.swap_dims({'obs': 'time'})
ds410 = ds410.chunk({'time': 1000})
ds410 = ds410.sortby('time')

ds411 = xr.open_dataset(TMPSF411)
ds411 = ds411.swap_dims({'obs': 'time'})
ds411 = ds411.chunk({'time': 1000})
ds411 = ds411.sortby('time')

ds412 = xr.open_dataset(TMPSF412)
ds412 = ds412.swap_dims({'obs': 'time'})
ds412 = ds412.chunk({'time': 1000})
ds412 = ds412.sortby('time')

ds413 = xr.open_dataset(TMPSF413)
ds413 = ds413.swap_dims({'obs': 'time'})
ds413 = ds413.chunk({'time': 1000})
ds413 = ds413.sortby('time')

ds414 = xr.open_dataset(TMPSF414)
ds414 = ds414.swap_dims({'obs': 'time'})
ds414 = ds414.chunk({'time': 1000})
ds414 = ds414.sortby('time')

ds415 = xr.open_dataset(TMPSF415)
ds415 = ds415.swap_dims({'obs': 'time'})
ds415 = ds415.chunk({'time': 1000})
ds415 = ds415.sortby('time')

ds416 = xr.open_dataset(TMPSF416)
ds416 = ds416.swap_dims({'obs': 'time'})
ds416 = ds416.chunk({'time': 1000})
ds416 = ds416.sortby('time')

ds417 = xr.open_dataset(TMPSF417)
ds417 = ds417.swap_dims({'obs': 'time'})
ds417 = ds417.chunk({'time': 1000})
ds417 = ds417.sortby('time')

ds418 = xr.open_dataset(TMPSF418)
ds418 = ds418.swap_dims({'obs': 'time'})
ds418 = ds418.chunk({'time': 1000})
ds418 = ds418.sortby('time')

ds419 = xr.open_dataset(TMPSF419)
ds419 = ds419.swap_dims({'obs': 'time'})
ds419 = ds419.chunk({'time': 1000})
ds419 = ds419.sortby('time')

ds420 = xr.open_dataset(TMPSF420)
ds420 = ds420.swap_dims({'obs': 'time'})
ds420 = ds420.chunk({'time': 1000})
ds420 = ds420.sortby('time')

ds421 = xr.open_dataset(TMPSF421)
ds421 = ds421.swap_dims({'obs': 'time'})
ds421 = ds421.chunk({'time': 1000})
ds421 = ds421.sortby('time')

ds422 = xr.open_dataset(TMPSF422)
ds422 = ds422.swap_dims({'obs': 'time'})
ds422 = ds422.chunk({'time': 1000})
ds422 = ds422.sortby('time')

ds423 = xr.open_dataset(TMPSF423)
ds423 = ds423.swap_dims({'obs': 'time'})
ds423 = ds423.chunk({'time': 1000})
ds423 = ds423.sortby('time')

ds424 = xr.open_dataset(TMPSF424)
ds424 = ds424.swap_dims({'obs': 'time'})
ds424 = ds424.chunk({'time': 1000})
ds424 = ds424.sortby('time')

ds425 = xr.open_dataset(TMPSF425)
ds425 = ds425.swap_dims({'obs': 'time'})
ds425 = ds425.chunk({'time': 1000})
ds425 = ds425.sortby('time')

ds426 = xr.open_dataset(TMPSF426)
ds426 = ds426.swap_dims({'obs': 'time'})
ds426 = ds426.chunk({'time': 1000})
ds426 = ds426.sortby('time')

ds427 = xr.open_dataset(TMPSF427)
ds427 = ds427.swap_dims({'obs': 'time'})
ds427 = ds427.chunk({'time': 1000})
ds427 = ds427.sortby('time')

ds428 = xr.open_dataset(TMPSF428)
ds428 = ds428.swap_dims({'obs': 'time'})
ds428 = ds428.chunk({'time': 1000})
ds428 = ds428.sortby('time')

ds429 = xr.open_dataset(TMPSF429)
ds429 = ds429.swap_dims({'obs': 'time'})
ds429 = ds429.chunk({'time': 1000})
ds429 = ds429.sortby('time')

ds430 = xr.open_dataset(TMPSF430)
ds430 = ds430.swap_dims({'obs': 'time'})
ds430 = ds430.chunk({'time': 1000})
ds430 = ds430.sortby('time')

ds431 = xr.open_dataset(TMPSF431)
ds431 = ds431.swap_dims({'obs': 'time'})
ds431 = ds431.chunk({'time': 1000})
ds431 = ds431.sortby('time')

ds432 = xr.open_dataset(TMPSF432)
ds432 = ds432.swap_dims({'obs': 'time'})
ds432 = ds432.chunk({'time': 1000})
ds432 = ds432.sortby('time')

ds433 = xr.open_dataset(TMPSF433)
ds433 = ds433.swap_dims({'obs': 'time'})
ds433 = ds433.chunk({'time': 1000})
ds433 = ds433.sortby('time')

ds434 = xr.open_dataset(TMPSF434)
ds434 = ds434.swap_dims({'obs': 'time'})
ds434 = ds434.chunk({'time': 1000})
ds434 = ds434.sortby('time')

ds435 = xr.open_dataset(TMPSF435)
ds435 = ds435.swap_dims({'obs': 'time'})
ds435 = ds435.chunk({'time': 1000})
ds435 = ds435.sortby('time')

ds436 = xr.open_dataset(TMPSF436)
ds436 = ds436.swap_dims({'obs': 'time'})
ds436 = ds436.chunk({'time': 1000})
ds436 = ds436.sortby('time')

ds437 = xr.open_dataset(TMPSF437)
ds437 = ds437.swap_dims({'obs': 'time'})
ds437 = ds437.chunk({'time': 1000})
ds437 = ds437.sortby('time')

ds438 = xr.open_dataset(TMPSF438)
ds438 = ds438.swap_dims({'obs': 'time'})
ds438 = ds438.chunk({'time': 1000})
ds438 = ds438.sortby('time')

ds439 = xr.open_dataset(TMPSF439)
ds439 = ds439.swap_dims({'obs': 'time'})
ds439 = ds439.chunk({'time': 1000})
ds439 = ds439.sortby('time')

ds440 = xr.open_dataset(TMPSF440)
ds440 = ds440.swap_dims({'obs': 'time'})
ds440 = ds440.chunk({'time': 1000})
ds440 = ds440.sortby('time')

ds441 = xr.open_dataset(TMPSF441)
ds441 = ds441.swap_dims({'obs': 'time'})
ds441 = ds441.chunk({'time': 1000})
ds441 = ds441.sortby('time')

ds442 = xr.open_dataset(TMPSF442)
ds442 = ds442.swap_dims({'obs': 'time'})
ds442 = ds442.chunk({'time': 1000})
ds442 = ds442.sortby('time')

ds443 = xr.open_dataset(TMPSF443)
ds443 = ds443.swap_dims({'obs': 'time'})
ds443 = ds443.chunk({'time': 1000})
ds443 = ds443.sortby('time')

ds444 = xr.open_dataset(TMPSF444)
ds444 = ds444.swap_dims({'obs': 'time'})
ds444 = ds444.chunk({'time': 1000})
ds444 = ds444.sortby('time')

ds445 = xr.open_dataset(TMPSF445)
ds445 = ds445.swap_dims({'obs': 'time'})
ds445 = ds445.chunk({'time': 1000})
ds445 = ds445.sortby('time')

ds446 = xr.open_dataset(TMPSF446)
ds446 = ds446.swap_dims({'obs': 'time'})
ds446 = ds446.chunk({'time': 1000})
ds446 = ds446.sortby('time')

ds447 = xr.open_dataset(TMPSF447)
ds447 = ds447.swap_dims({'obs': 'time'})
ds447 = ds447.chunk({'time': 1000})
ds447 = ds447.sortby('time')

ds448 = xr.open_dataset(TMPSF448)
ds448 = ds448.swap_dims({'obs': 'time'})
ds448 = ds448.chunk({'time': 1000})
ds448 = ds448.sortby('time')

ds449 = xr.open_dataset(TMPSF449)
ds449 = ds449.swap_dims({'obs': 'time'})
ds449 = ds449.chunk({'time': 1000})
ds449 = ds449.sortby('time')

ds450 = xr.open_dataset(TMPSF450)
ds450 = ds450.swap_dims({'obs': 'time'})
ds450 = ds450.chunk({'time': 1000})
ds450 = ds450.sortby('time')

ds451 = xr.open_dataset(TMPSF451)
ds451 = ds451.swap_dims({'obs': 'time'})
ds451 = ds451.chunk({'time': 1000})
ds451 = ds451.sortby('time')

ds452 = xr.open_dataset(TMPSF452)
ds452 = ds452.swap_dims({'obs': 'time'})
ds452 = ds452.chunk({'time': 1000})
ds452 = ds452.sortby('time')

ds453 = xr.open_dataset(TMPSF453)
ds453 = ds453.swap_dims({'obs': 'time'})
ds453 = ds453.chunk({'time': 1000})
ds453 = ds453.sortby('time')

ds454 = xr.open_dataset(TMPSF454)
ds454 = ds454.swap_dims({'obs': 'time'})
ds454 = ds454.chunk({'time': 1000})
ds454 = ds454.sortby('time')

ds455 = xr.open_dataset(TMPSF455)
ds455 = ds455.swap_dims({'obs': 'time'})
ds455 = ds455.chunk({'time': 1000})
ds455 = ds455.sortby('time')

ds456 = xr.open_dataset(TMPSF456)
ds456 = ds456.swap_dims({'obs': 'time'})
ds456 = ds456.chunk({'time': 1000})
ds456 = ds456.sortby('time')

ds457 = xr.open_dataset(TMPSF457)
ds457 = ds457.swap_dims({'obs': 'time'})
ds457 = ds457.chunk({'time': 1000})
ds457 = ds457.sortby('time')

ds458 = xr.open_dataset(TMPSF458)
ds458 = ds458.swap_dims({'obs': 'time'})
ds458 = ds458.chunk({'time': 1000})
ds458 = ds458.sortby('time')

ds459 = xr.open_dataset(TMPSF459)
ds459 = ds459.swap_dims({'obs': 'time'})
ds459 = ds459.chunk({'time': 1000})
ds459 = ds459.sortby('time')

ds460 = xr.open_dataset(TMPSF460)
ds460 = ds460.swap_dims({'obs': 'time'})
ds460 = ds460.chunk({'time': 1000})
ds460 = ds460.sortby('time')

ds461 = xr.open_dataset(TMPSF461)
ds461 = ds461.swap_dims({'obs': 'time'})
ds461 = ds461.chunk({'time': 1000})
ds461 = ds461.sortby('time')

ds462 = xr.open_dataset(TMPSF462)
ds462 = ds462.swap_dims({'obs': 'time'})
ds462 = ds462.chunk({'time': 1000})
ds462 = ds462.sortby('time')

ds463 = xr.open_dataset(TMPSF463)
ds463 = ds463.swap_dims({'obs': 'time'})
ds463 = ds463.chunk({'time': 1000})
ds463 = ds463.sortby('time')

ds464 = xr.open_dataset(TMPSF464)
ds464 = ds464.swap_dims({'obs': 'time'})
ds464 = ds464.chunk({'time': 1000})
ds464 = ds464.sortby('time')

ds465 = xr.open_dataset(TMPSF465)
ds465 = ds465.swap_dims({'obs': 'time'})
ds465 = ds465.chunk({'time': 1000})
ds465 = ds465.sortby('time')

ds466 = xr.open_dataset(TMPSF466)
ds466 = ds466.swap_dims({'obs': 'time'})
ds466 = ds466.chunk({'time': 1000})
ds466 = ds466.sortby('time')

ds467 = xr.open_dataset(TMPSF467)
ds467 = ds467.swap_dims({'obs': 'time'})
ds467 = ds467.chunk({'time': 1000})
ds467 = ds467.sortby('time')

ds468 = xr.open_dataset(TMPSF468)
ds468 = ds468.swap_dims({'obs': 'time'})
ds468 = ds468.chunk({'time': 1000})
ds468 = ds468.sortby('time')

ds469 = xr.open_dataset(TMPSF469)
ds469 = ds469.swap_dims({'obs': 'time'})
ds469 = ds469.chunk({'time': 1000})
ds469 = ds469.sortby('time')

ds470 = xr.open_dataset(TMPSF470)
ds470 = ds470.swap_dims({'obs': 'time'})
ds470 = ds470.chunk({'time': 1000})
ds470 = ds470.sortby('time')

ds471 = xr.open_dataset(TMPSF471)
ds471 = ds471.swap_dims({'obs': 'time'})
ds471 = ds471.chunk({'time': 1000})
ds471 = ds471.sortby('time')

ds472 = xr.open_dataset(TMPSF472)
ds472 = ds472.swap_dims({'obs': 'time'})
ds472 = ds472.chunk({'time': 1000})
ds472 = ds472.sortby('time')

ds473 = xr.open_dataset(TMPSF473)
ds473 = ds473.swap_dims({'obs': 'time'})
ds473 = ds473.chunk({'time': 1000})
ds473 = ds473.sortby('time')

ds474 = xr.open_dataset(TMPSF474)
ds474 = ds474.swap_dims({'obs': 'time'})
ds474 = ds474.chunk({'time': 1000})
ds474 = ds474.sortby('time')

ds475 = xr.open_dataset(TMPSF475)
ds475 = ds475.swap_dims({'obs': 'time'})
ds475 = ds475.chunk({'time': 1000})
ds475 = ds475.sortby('time')

ds476 = xr.open_dataset(TMPSF476)
ds476 = ds476.swap_dims({'obs': 'time'})
ds476 = ds476.chunk({'time': 1000})
ds476 = ds476.sortby('time')

ds477 = xr.open_dataset(TMPSF477)
ds477 = ds477.swap_dims({'obs': 'time'})
ds477 = ds477.chunk({'time': 1000})
ds477 = ds477.sortby('time')

ds478 = xr.open_dataset(TMPSF478)
ds478 = ds478.swap_dims({'obs': 'time'})
ds478 = ds478.chunk({'time': 1000})
ds478 = ds478.sortby('time')

ds479 = xr.open_dataset(TMPSF479)
ds479 = ds479.swap_dims({'obs': 'time'})
ds479 = ds479.chunk({'time': 1000})
ds479 = ds479.sortby('time')

ds480 = xr.open_dataset(TMPSF480)
ds480 = ds480.swap_dims({'obs': 'time'})
ds480 = ds480.chunk({'time': 1000})
ds480 = ds480.sortby('time')

ds481 = xr.open_dataset(TMPSF481)
ds481 = ds481.swap_dims({'obs': 'time'})
ds481 = ds481.chunk({'time': 1000})
ds481 = ds481.sortby('time')

ds482 = xr.open_dataset(TMPSF482)
ds482 = ds482.swap_dims({'obs': 'time'})
ds482 = ds482.chunk({'time': 1000})
ds482 = ds482.sortby('time')

ds483 = xr.open_dataset(TMPSF483)
ds483 = ds483.swap_dims({'obs': 'time'})
ds483 = ds483.chunk({'time': 1000})
ds483 = ds483.sortby('time')

ds484 = xr.open_dataset(TMPSF484)
ds484 = ds484.swap_dims({'obs': 'time'})
ds484 = ds484.chunk({'time': 1000})
ds484 = ds484.sortby('time')

ds485 = xr.open_dataset(TMPSF485)
ds485 = ds485.swap_dims({'obs': 'time'})
ds485 = ds485.chunk({'time': 1000})
ds485 = ds485.sortby('time')

ds486 = xr.open_dataset(TMPSF486)
ds486 = ds486.swap_dims({'obs': 'time'})
ds486 = ds486.chunk({'time': 1000})
ds486 = ds486.sortby('time')

ds487 = xr.open_dataset(TMPSF487)
ds487 = ds487.swap_dims({'obs': 'time'})
ds487 = ds487.chunk({'time': 1000})
ds487 = ds487.sortby('time')

ds488 = xr.open_dataset(TMPSF488)
ds488 = ds488.swap_dims({'obs': 'time'})
ds488 = ds488.chunk({'time': 1000})
ds488 = ds488.sortby('time')

ds489 = xr.open_dataset(TMPSF489)
ds489 = ds489.swap_dims({'obs': 'time'})
ds489 = ds489.chunk({'time': 1000})
ds489 = ds489.sortby('time')

ds490 = xr.open_dataset(TMPSF490)
ds490 = ds490.swap_dims({'obs': 'time'})
ds490 = ds490.chunk({'time': 1000})
ds490 = ds490.sortby('time')

ds491 = xr.open_dataset(TMPSF491)
ds491 = ds491.swap_dims({'obs': 'time'})
ds491 = ds491.chunk({'time': 1000})
ds491 = ds491.sortby('time')

ds492 = xr.open_dataset(TMPSF492)
ds492 = ds492.swap_dims({'obs': 'time'})
ds492 = ds492.chunk({'time': 1000})
ds492 = ds492.sortby('time')

ds493 = xr.open_dataset(TMPSF493)
ds493 = ds493.swap_dims({'obs': 'time'})
ds493 = ds493.chunk({'time': 1000})
ds493 = ds493.sortby('time')

ds494 = xr.open_dataset(TMPSF494)
ds494 = ds494.swap_dims({'obs': 'time'})
ds494 = ds494.chunk({'time': 1000})
ds494 = ds494.sortby('time')

ds495 = xr.open_dataset(TMPSF495)
ds495 = ds495.swap_dims({'obs': 'time'})
ds495 = ds495.chunk({'time': 1000})
ds495 = ds495.sortby('time')

ds496 = xr.open_dataset(TMPSF496)
ds496 = ds496.swap_dims({'obs': 'time'})
ds496 = ds496.chunk({'time': 1000})
ds496 = ds496.sortby('time')

ds497 = xr.open_dataset(TMPSF497)
ds497 = ds497.swap_dims({'obs': 'time'})
ds497 = ds497.chunk({'time': 1000})
ds497 = ds497.sortby('time')

ds498 = xr.open_dataset(TMPSF498)
ds498 = ds498.swap_dims({'obs': 'time'})
ds498 = ds498.chunk({'time': 1000})
ds498 = ds498.sortby('time')

ds499 = xr.open_dataset(TMPSF499)
ds499 = ds499.swap_dims({'obs': 'time'})
ds499 = ds499.chunk({'time': 1000})
ds499 = ds499.sortby('time')

ds500 = xr.open_dataset(TMPSF500)
ds500 = ds500.swap_dims({'obs': 'time'})
ds500 = ds500.chunk({'time': 1000})
ds500 = ds500.sortby('time')

ds501 = xr.open_dataset(TMPSF501)
ds501 = ds501.swap_dims({'obs': 'time'})
ds501 = ds501.chunk({'time': 1000})
ds501 = ds501.sortby('time')

ds502 = xr.open_dataset(TMPSF502)
ds502 = ds502.swap_dims({'obs': 'time'})
ds502 = ds502.chunk({'time': 1000})
ds502 = ds502.sortby('time')

ds503 = xr.open_dataset(TMPSF503)
ds503 = ds503.swap_dims({'obs': 'time'})
ds503 = ds503.chunk({'time': 1000})
ds503 = ds503.sortby('time')

ds504 = xr.open_dataset(TMPSF504)
ds504 = ds504.swap_dims({'obs': 'time'})
ds504 = ds504.chunk({'time': 1000})
ds504 = ds504.sortby('time')

ds505 = xr.open_dataset(TMPSF505)
ds505 = ds505.swap_dims({'obs': 'time'})
ds505 = ds505.chunk({'time': 1000})
ds505 = ds505.sortby('time')

ds506 = xr.open_dataset(TMPSF506)
ds506 = ds506.swap_dims({'obs': 'time'})
ds506 = ds506.chunk({'time': 1000})
ds506 = ds506.sortby('time')

ds507 = xr.open_dataset(TMPSF507)
ds507 = ds507.swap_dims({'obs': 'time'})
ds507 = ds507.chunk({'time': 1000})
ds507 = ds507.sortby('time')

ds508 = xr.open_dataset(TMPSF508)
ds508 = ds508.swap_dims({'obs': 'time'})
ds508 = ds508.chunk({'time': 1000})
ds508 = ds508.sortby('time')

ds509 = xr.open_dataset(TMPSF509)
ds509 = ds509.swap_dims({'obs': 'time'})
ds509 = ds509.chunk({'time': 1000})
ds509 = ds509.sortby('time')

ds510 = xr.open_dataset(TMPSF510)
ds510 = ds510.swap_dims({'obs': 'time'})
ds510 = ds510.chunk({'time': 1000})
ds510 = ds510.sortby('time')

ds511 = xr.open_dataset(TMPSF511)
ds511 = ds511.swap_dims({'obs': 'time'})
ds511 = ds511.chunk({'time': 1000})
ds511 = ds511.sortby('time')

ds512 = xr.open_dataset(TMPSF512)
ds512 = ds512.swap_dims({'obs': 'time'})
ds512 = ds512.chunk({'time': 1000})
ds512 = ds512.sortby('time')

ds513 = xr.open_dataset(TMPSF513)
ds513 = ds513.swap_dims({'obs': 'time'})
ds513 = ds513.chunk({'time': 1000})
ds513 = ds513.sortby('time')

ds514 = xr.open_dataset(TMPSF514)
ds514 = ds514.swap_dims({'obs': 'time'})
ds514 = ds514.chunk({'time': 1000})
ds514 = ds514.sortby('time')

ds515 = xr.open_dataset(TMPSF515)
ds515 = ds515.swap_dims({'obs': 'time'})
ds515 = ds515.chunk({'time': 1000})
ds515 = ds515.sortby('time')

ds516 = xr.open_dataset(TMPSF516)
ds516 = ds516.swap_dims({'obs': 'time'})
ds516 = ds516.chunk({'time': 1000})
ds516 = ds516.sortby('time')

ds517 = xr.open_dataset(TMPSF517)
ds517 = ds517.swap_dims({'obs': 'time'})
ds517 = ds517.chunk({'time': 1000})
ds517 = ds517.sortby('time')

ds518 = xr.open_dataset(TMPSF518)
ds518 = ds518.swap_dims({'obs': 'time'})
ds518 = ds518.chunk({'time': 1000})
ds518 = ds518.sortby('time')

ds519 = xr.open_dataset(TMPSF519)
ds519 = ds519.swap_dims({'obs': 'time'})
ds519 = ds519.chunk({'time': 1000})
ds519 = ds519.sortby('time')

ds520 = xr.open_dataset(TMPSF520)
ds520 = ds520.swap_dims({'obs': 'time'})
ds520 = ds520.chunk({'time': 1000})
ds520 = ds520.sortby('time')

ds521 = xr.open_dataset(TMPSF521)
ds521 = ds521.swap_dims({'obs': 'time'})
ds521 = ds521.chunk({'time': 1000})
ds521 = ds521.sortby('time')

ds522 = xr.open_dataset(TMPSF522)
ds522 = ds522.swap_dims({'obs': 'time'})
ds522 = ds522.chunk({'time': 1000})
ds522 = ds522.sortby('time')

ds523 = xr.open_dataset(TMPSF523)
ds523 = ds523.swap_dims({'obs': 'time'})
ds523 = ds523.chunk({'time': 1000})
ds523 = ds523.sortby('time')

ds524 = xr.open_dataset(TMPSF524)
ds524 = ds524.swap_dims({'obs': 'time'})
ds524 = ds524.chunk({'time': 1000})
ds524 = ds524.sortby('time')

ds525 = xr.open_dataset(TMPSF525)
ds525 = ds525.swap_dims({'obs': 'time'})
ds525 = ds525.chunk({'time': 1000})
ds525 = ds525.sortby('time')

ds526 = xr.open_dataset(TMPSF526)
ds526 = ds526.swap_dims({'obs': 'time'})
ds526 = ds526.chunk({'time': 1000})
ds526 = ds526.sortby('time')

ds527 = xr.open_dataset(TMPSF527)
ds527 = ds527.swap_dims({'obs': 'time'})
ds527 = ds527.chunk({'time': 1000})
ds527 = ds527.sortby('time')

ds528 = xr.open_dataset(TMPSF528)
ds528 = ds528.swap_dims({'obs': 'time'})
ds528 = ds528.chunk({'time': 1000})
ds528 = ds528.sortby('time')

ds529 = xr.open_dataset(TMPSF529)
ds529 = ds529.swap_dims({'obs': 'time'})
ds529 = ds529.chunk({'time': 1000})
ds529 = ds529.sortby('time')

ds530 = xr.open_dataset(TMPSF530)
ds530 = ds530.swap_dims({'obs': 'time'})
ds530 = ds530.chunk({'time': 1000})
ds530 = ds530.sortby('time')

ds531 = xr.open_dataset(TMPSF531)
ds531 = ds531.swap_dims({'obs': 'time'})
ds531 = ds531.chunk({'time': 1000})
ds531 = ds531.sortby('time')

ds532 = xr.open_dataset(TMPSF532)
ds532 = ds532.swap_dims({'obs': 'time'})
ds532 = ds532.chunk({'time': 1000})
ds532 = ds532.sortby('time')

ds533 = xr.open_dataset(TMPSF533)
ds533 = ds533.swap_dims({'obs': 'time'})
ds533 = ds533.chunk({'time': 1000})
ds533 = ds533.sortby('time')

ds534 = xr.open_dataset(TMPSF534)
ds534 = ds534.swap_dims({'obs': 'time'})
ds534 = ds534.chunk({'time': 1000})
ds534 = ds534.sortby('time')

ds535 = xr.open_dataset(TMPSF535)
ds535 = ds535.swap_dims({'obs': 'time'})
ds535 = ds535.chunk({'time': 1000})
ds535 = ds535.sortby('time')

ds536 = xr.open_dataset(TMPSF536)
ds536 = ds536.swap_dims({'obs': 'time'})
ds536 = ds536.chunk({'time': 1000})
ds536 = ds536.sortby('time')

ds537 = xr.open_dataset(TMPSF537)
ds537 = ds537.swap_dims({'obs': 'time'})
ds537 = ds537.chunk({'time': 1000})
ds537 = ds537.sortby('time')

ds538 = xr.open_dataset(TMPSF538)
ds538 = ds538.swap_dims({'obs': 'time'})
ds538 = ds538.chunk({'time': 1000})
ds538 = ds538.sortby('time')

ds539 = xr.open_dataset(TMPSF539)
ds539 = ds539.swap_dims({'obs': 'time'})
ds539 = ds539.chunk({'time': 1000})
ds539 = ds539.sortby('time')

ds540 = xr.open_dataset(TMPSF540)
ds540 = ds540.swap_dims({'obs': 'time'})
ds540 = ds540.chunk({'time': 1000})
ds540 = ds540.sortby('time')

ds541 = xr.open_dataset(TMPSF541)
ds541 = ds541.swap_dims({'obs': 'time'})
ds541 = ds541.chunk({'time': 1000})
ds541 = ds541.sortby('time')

ds542 = xr.open_dataset(TMPSF542)
ds542 = ds542.swap_dims({'obs': 'time'})
ds542 = ds542.chunk({'time': 1000})
ds542 = ds542.sortby('time')

ds543 = xr.open_dataset(TMPSF543)
ds543 = ds543.swap_dims({'obs': 'time'})
ds543 = ds543.chunk({'time': 1000})
ds543 = ds543.sortby('time')

ds544 = xr.open_dataset(TMPSF544)
ds544 = ds544.swap_dims({'obs': 'time'})
ds544 = ds544.chunk({'time': 1000})
ds544 = ds544.sortby('time')

ds545 = xr.open_dataset(TMPSF545)
ds545 = ds545.swap_dims({'obs': 'time'})
ds545 = ds545.chunk({'time': 1000})
ds545 = ds545.sortby('time')

ds546 = xr.open_dataset(TMPSF546)
ds546 = ds546.swap_dims({'obs': 'time'})
ds546 = ds546.chunk({'time': 1000})
ds546 = ds546.sortby('time')

ds547 = xr.open_dataset(TMPSF547)
ds547 = ds547.swap_dims({'obs': 'time'})
ds547 = ds547.chunk({'time': 1000})
ds547 = ds547.sortby('time')

ds548 = xr.open_dataset(TMPSF548)
ds548 = ds548.swap_dims({'obs': 'time'})
ds548 = ds548.chunk({'time': 1000})
ds548 = ds548.sortby('time')

ds549 = xr.open_dataset(TMPSF549)
ds549 = ds549.swap_dims({'obs': 'time'})
ds549 = ds549.chunk({'time': 1000})
ds549 = ds549.sortby('time')

ds550 = xr.open_dataset(TMPSF550)
ds550 = ds550.swap_dims({'obs': 'time'})
ds550 = ds550.chunk({'time': 1000})
ds550 = ds550.sortby('time')

ds551 = xr.open_dataset(TMPSF551)
ds551 = ds551.swap_dims({'obs': 'time'})
ds551 = ds551.chunk({'time': 1000})
ds551 = ds551.sortby('time')

ds552 = xr.open_dataset(TMPSF552)
ds552 = ds552.swap_dims({'obs': 'time'})
ds552 = ds552.chunk({'time': 1000})
ds552 = ds552.sortby('time')

ds553 = xr.open_dataset(TMPSF553)
ds553 = ds553.swap_dims({'obs': 'time'})
ds553 = ds553.chunk({'time': 1000})
ds553 = ds553.sortby('time')

ds554 = xr.open_dataset(TMPSF554)
ds554 = ds554.swap_dims({'obs': 'time'})
ds554 = ds554.chunk({'time': 1000})
ds554 = ds554.sortby('time')

ds555 = xr.open_dataset(TMPSF555)
ds555 = ds555.swap_dims({'obs': 'time'})
ds555 = ds555.chunk({'time': 1000})
ds555 = ds555.sortby('time')

ds556 = xr.open_dataset(TMPSF556)
ds556 = ds556.swap_dims({'obs': 'time'})
ds556 = ds556.chunk({'time': 1000})
ds556 = ds556.sortby('time')

ds557 = xr.open_dataset(TMPSF557)
ds557 = ds557.swap_dims({'obs': 'time'})
ds557 = ds557.chunk({'time': 1000})
ds557 = ds557.sortby('time')

ds558 = xr.open_dataset(TMPSF558)
ds558 = ds558.swap_dims({'obs': 'time'})
ds558 = ds558.chunk({'time': 1000})
ds558 = ds558.sortby('time')

ds559 = xr.open_dataset(TMPSF559)
ds559 = ds559.swap_dims({'obs': 'time'})
ds559 = ds559.chunk({'time': 1000})
ds559 = ds559.sortby('time')

ds560 = xr.open_dataset(TMPSF560)
ds560 = ds560.swap_dims({'obs': 'time'})
ds560 = ds560.chunk({'time': 1000})
ds560 = ds560.sortby('time')

ds561 = xr.open_dataset(TMPSF561)
ds561 = ds561.swap_dims({'obs': 'time'})
ds561 = ds561.chunk({'time': 1000})
ds561 = ds561.sortby('time')

ds562 = xr.open_dataset(TMPSF562)
ds562 = ds562.swap_dims({'obs': 'time'})
ds562 = ds562.chunk({'time': 1000})
ds562 = ds562.sortby('time')

ds563 = xr.open_dataset(TMPSF563)
ds563 = ds563.swap_dims({'obs': 'time'})
ds563 = ds563.chunk({'time': 1000})
ds563 = ds563.sortby('time')

ds564 = xr.open_dataset(TMPSF564)
ds564 = ds564.swap_dims({'obs': 'time'})
ds564 = ds564.chunk({'time': 1000})
ds564 = ds564.sortby('time')

ds565 = xr.open_dataset(TMPSF565)
ds565 = ds565.swap_dims({'obs': 'time'})
ds565 = ds565.chunk({'time': 1000})
ds565 = ds565.sortby('time')

ds566 = xr.open_dataset(TMPSF566)
ds566 = ds566.swap_dims({'obs': 'time'})
ds566 = ds566.chunk({'time': 1000})
ds566 = ds566.sortby('time')

ds567 = xr.open_dataset(TMPSF567)
ds567 = ds567.swap_dims({'obs': 'time'})
ds567 = ds567.chunk({'time': 1000})
ds567 = ds567.sortby('time')

ds568 = xr.open_dataset(TMPSF568)
ds568 = ds568.swap_dims({'obs': 'time'})
ds568 = ds568.chunk({'time': 1000})
ds568 = ds568.sortby('time')

ds569 = xr.open_dataset(TMPSF569)
ds569 = ds569.swap_dims({'obs': 'time'})
ds569 = ds569.chunk({'time': 1000})
ds569 = ds569.sortby('time')

ds570 = xr.open_dataset(TMPSF570)
ds570 = ds570.swap_dims({'obs': 'time'})
ds570 = ds570.chunk({'time': 1000})
ds570 = ds570.sortby('time')

ds571 = xr.open_dataset(TMPSF571)
ds571 = ds571.swap_dims({'obs': 'time'})
ds571 = ds571.chunk({'time': 1000})
ds571 = ds571.sortby('time')

ds572 = xr.open_dataset(TMPSF572)
ds572 = ds572.swap_dims({'obs': 'time'})
ds572 = ds572.chunk({'time': 1000})
ds572 = ds572.sortby('time')

ds573 = xr.open_dataset(TMPSF573)
ds573 = ds573.swap_dims({'obs': 'time'})
ds573 = ds573.chunk({'time': 1000})
ds573 = ds573.sortby('time')

ds574 = xr.open_dataset(TMPSF574)
ds574 = ds574.swap_dims({'obs': 'time'})
ds574 = ds574.chunk({'time': 1000})
ds574 = ds574.sortby('time')

ds575 = xr.open_dataset(TMPSF575)
ds575 = ds575.swap_dims({'obs': 'time'})
ds575 = ds575.chunk({'time': 1000})
ds575 = ds575.sortby('time')

ds576 = xr.open_dataset(TMPSF576)
ds576 = ds576.swap_dims({'obs': 'time'})
ds576 = ds576.chunk({'time': 1000})
ds576 = ds576.sortby('time')

ds577 = xr.open_dataset(TMPSF577)
ds577 = ds577.swap_dims({'obs': 'time'})
ds577 = ds577.chunk({'time': 1000})
ds577 = ds577.sortby('time')

ds578 = xr.open_dataset(TMPSF578)
ds578 = ds578.swap_dims({'obs': 'time'})
ds578 = ds578.chunk({'time': 1000})
ds578 = ds578.sortby('time')

ds579 = xr.open_dataset(TMPSF579)
ds579 = ds579.swap_dims({'obs': 'time'})
ds579 = ds579.chunk({'time': 1000})
ds579 = ds579.sortby('time')

ds580 = xr.open_dataset(TMPSF580)
ds580 = ds580.swap_dims({'obs': 'time'})
ds580 = ds580.chunk({'time': 1000})
ds580 = ds580.sortby('time')

ds581 = xr.open_dataset(TMPSF581)
ds581 = ds581.swap_dims({'obs': 'time'})
ds581 = ds581.chunk({'time': 1000})
ds581 = ds581.sortby('time')

ds582 = xr.open_dataset(TMPSF582)
ds582 = ds582.swap_dims({'obs': 'time'})
ds582 = ds582.chunk({'time': 1000})
ds582 = ds582.sortby('time')

ds583 = xr.open_dataset(TMPSF583)
ds583 = ds583.swap_dims({'obs': 'time'})
ds583 = ds583.chunk({'time': 1000})
ds583 = ds583.sortby('time')

ds584 = xr.open_dataset(TMPSF584)
ds584 = ds584.swap_dims({'obs': 'time'})
ds584 = ds584.chunk({'time': 1000})
ds584 = ds584.sortby('time')

ds585 = xr.open_dataset(TMPSF585)
ds585 = ds585.swap_dims({'obs': 'time'})
ds585 = ds585.chunk({'time': 1000})
ds585 = ds585.sortby('time')

ds586 = xr.open_dataset(TMPSF586)
ds586 = ds586.swap_dims({'obs': 'time'})
ds586 = ds586.chunk({'time': 1000})
ds586 = ds586.sortby('time')

ds587 = xr.open_dataset(TMPSF587)
ds587 = ds587.swap_dims({'obs': 'time'})
ds587 = ds587.chunk({'time': 1000})
ds587 = ds587.sortby('time')

ds588 = xr.open_dataset(TMPSF588)
ds588 = ds588.swap_dims({'obs': 'time'})
ds588 = ds588.chunk({'time': 1000})
ds588 = ds588.sortby('time')

ds589 = xr.open_dataset(TMPSF589)
ds589 = ds589.swap_dims({'obs': 'time'})
ds589 = ds589.chunk({'time': 1000})
ds589 = ds589.sortby('time')

ds590 = xr.open_dataset(TMPSF590)
ds590 = ds590.swap_dims({'obs': 'time'})
ds590 = ds590.chunk({'time': 1000})
ds590 = ds590.sortby('time')

ds591 = xr.open_dataset(TMPSF591)
ds591 = ds591.swap_dims({'obs': 'time'})
ds591 = ds591.chunk({'time': 1000})
ds591 = ds591.sortby('time')

ds592 = xr.open_dataset(TMPSF592)
ds592 = ds592.swap_dims({'obs': 'time'})
ds592 = ds592.chunk({'time': 1000})
ds592 = ds592.sortby('time')

ds593 = xr.open_dataset(TMPSF593)
ds593 = ds593.swap_dims({'obs': 'time'})
ds593 = ds593.chunk({'time': 1000})
ds593 = ds593.sortby('time')

ds594 = xr.open_dataset(TMPSF594)
ds594 = ds594.swap_dims({'obs': 'time'})
ds594 = ds594.chunk({'time': 1000})
ds594 = ds594.sortby('time')

ds595 = xr.open_dataset(TMPSF595)
ds595 = ds595.swap_dims({'obs': 'time'})
ds595 = ds595.chunk({'time': 1000})
ds595 = ds595.sortby('time')

ds596 = xr.open_dataset(TMPSF596)
ds596 = ds596.swap_dims({'obs': 'time'})
ds596 = ds596.chunk({'time': 1000})
ds596 = ds596.sortby('time')

ds597 = xr.open_dataset(TMPSF597)
ds597 = ds597.swap_dims({'obs': 'time'})
ds597 = ds597.chunk({'time': 1000})
ds597 = ds597.sortby('time')

ds598 = xr.open_dataset(TMPSF598)
ds598 = ds598.swap_dims({'obs': 'time'})
ds598 = ds598.chunk({'time': 1000})
ds598 = ds598.sortby('time')

ds599 = xr.open_dataset(TMPSF599)
ds599 = ds599.swap_dims({'obs': 'time'})
ds599 = ds599.chunk({'time': 1000})
ds599 = ds599.sortby('time')

ds600 = xr.open_dataset(TMPSF600)
ds600 = ds600.swap_dims({'obs': 'time'})
ds600 = ds600.chunk({'time': 1000})
ds600 = ds600.sortby('time')

ds601 = xr.open_dataset(TMPSF601)
ds601 = ds601.swap_dims({'obs': 'time'})
ds601 = ds601.chunk({'time': 1000})
ds601 = ds601.sortby('time')

ds602 = xr.open_dataset(TMPSF602)
ds602 = ds602.swap_dims({'obs': 'time'})
ds602 = ds602.chunk({'time': 1000})
ds602 = ds602.sortby('time')

ds603 = xr.open_dataset(TMPSF603)
ds603 = ds603.swap_dims({'obs': 'time'})
ds603 = ds603.chunk({'time': 1000})
ds603 = ds603.sortby('time')

ds604 = xr.open_dataset(TMPSF604)
ds604 = ds604.swap_dims({'obs': 'time'})
ds604 = ds604.chunk({'time': 1000})
ds604 = ds604.sortby('time')

ds605 = xr.open_dataset(TMPSF605)
ds605 = ds605.swap_dims({'obs': 'time'})
ds605 = ds605.chunk({'time': 1000})
ds605 = ds605.sortby('time')

ds606 = xr.open_dataset(TMPSF606)
ds606 = ds606.swap_dims({'obs': 'time'})
ds606 = ds606.chunk({'time': 1000})
ds606 = ds606.sortby('time')

ds607 = xr.open_dataset(TMPSF607)
ds607 = ds607.swap_dims({'obs': 'time'})
ds607 = ds607.chunk({'time': 1000})
ds607 = ds607.sortby('time')

ds608 = xr.open_dataset(TMPSF608)
ds608 = ds608.swap_dims({'obs': 'time'})
ds608 = ds608.chunk({'time': 1000})
ds608 = ds608.sortby('time')

ds609 = xr.open_dataset(TMPSF609)
ds609 = ds609.swap_dims({'obs': 'time'})
ds609 = ds609.chunk({'time': 1000})
ds609 = ds609.sortby('time')

ds610 = xr.open_dataset(TMPSF610)
ds610 = ds610.swap_dims({'obs': 'time'})
ds610 = ds610.chunk({'time': 1000})
ds610 = ds610.sortby('time')

ds611 = xr.open_dataset(TMPSF611)
ds611 = ds611.swap_dims({'obs': 'time'})
ds611 = ds611.chunk({'time': 1000})
ds611 = ds611.sortby('time')

ds612 = xr.open_dataset(TMPSF612)
ds612 = ds612.swap_dims({'obs': 'time'})
ds612 = ds612.chunk({'time': 1000})
ds612 = ds612.sortby('time')

ds613 = xr.open_dataset(TMPSF613)
ds613 = ds613.swap_dims({'obs': 'time'})
ds613 = ds613.chunk({'time': 1000})
ds613 = ds613.sortby('time')

ds614 = xr.open_dataset(TMPSF614)
ds614 = ds614.swap_dims({'obs': 'time'})
ds614 = ds614.chunk({'time': 1000})
ds614 = ds614.sortby('time')

ds615 = xr.open_dataset(TMPSF615)
ds615 = ds615.swap_dims({'obs': 'time'})
ds615 = ds615.chunk({'time': 1000})
ds615 = ds615.sortby('time')

ds616 = xr.open_dataset(TMPSF616)
ds616 = ds616.swap_dims({'obs': 'time'})
ds616 = ds616.chunk({'time': 1000})
ds616 = ds616.sortby('time')

ds617 = xr.open_dataset(TMPSF617)
ds617 = ds617.swap_dims({'obs': 'time'})
ds617 = ds617.chunk({'time': 1000})
ds617 = ds617.sortby('time')

ds618 = xr.open_dataset(TMPSF618)
ds618 = ds618.swap_dims({'obs': 'time'})
ds618 = ds618.chunk({'time': 1000})
ds618 = ds618.sortby('time')

ds619 = xr.open_dataset(TMPSF619)
ds619 = ds619.swap_dims({'obs': 'time'})
ds619 = ds619.chunk({'time': 1000})
ds619 = ds619.sortby('time')

ds620 = xr.open_dataset(TMPSF620)
ds620 = ds620.swap_dims({'obs': 'time'})
ds620 = ds620.chunk({'time': 1000})
ds620 = ds620.sortby('time')

ds621 = xr.open_dataset(TMPSF621)
ds621 = ds621.swap_dims({'obs': 'time'})
ds621 = ds621.chunk({'time': 1000})
ds621 = ds621.sortby('time')

ds622 = xr.open_dataset(TMPSF622)
ds622 = ds622.swap_dims({'obs': 'time'})
ds622 = ds622.chunk({'time': 1000})
ds622 = ds622.sortby('time')

ds623 = xr.open_dataset(TMPSF623)
ds623 = ds623.swap_dims({'obs': 'time'})
ds623 = ds623.chunk({'time': 1000})
ds623 = ds623.sortby('time')

ds624 = xr.open_dataset(TMPSF624)
ds624 = ds624.swap_dims({'obs': 'time'})
ds624 = ds624.chunk({'time': 1000})
ds624 = ds624.sortby('time')

ds625 = xr.open_dataset(TMPSF625)
ds625 = ds625.swap_dims({'obs': 'time'})
ds625 = ds625.chunk({'time': 1000})
ds625 = ds625.sortby('time')

ds626 = xr.open_dataset(TMPSF626)
ds626 = ds626.swap_dims({'obs': 'time'})
ds626 = ds626.chunk({'time': 1000})
ds626 = ds626.sortby('time')

ds627 = xr.open_dataset(TMPSF627)
ds627 = ds627.swap_dims({'obs': 'time'})
ds627 = ds627.chunk({'time': 1000})
ds627 = ds627.sortby('time')

ds628 = xr.open_dataset(TMPSF628)
ds628 = ds628.swap_dims({'obs': 'time'})
ds628 = ds628.chunk({'time': 1000})
ds628 = ds628.sortby('time')

ds629 = xr.open_dataset(TMPSF629)
ds629 = ds629.swap_dims({'obs': 'time'})
ds629 = ds629.chunk({'time': 1000})
ds629 = ds629.sortby('time')

ds630 = xr.open_dataset(TMPSF630)
ds630 = ds630.swap_dims({'obs': 'time'})
ds630 = ds630.chunk({'time': 1000})
ds630 = ds630.sortby('time')

ds631 = xr.open_dataset(TMPSF631)
ds631 = ds631.swap_dims({'obs': 'time'})
ds631 = ds631.chunk({'time': 1000})
ds631 = ds631.sortby('time')

ds632 = xr.open_dataset(TMPSF632)
ds632 = ds632.swap_dims({'obs': 'time'})
ds632 = ds632.chunk({'time': 1000})
ds632 = ds632.sortby('time')

ds633 = xr.open_dataset(TMPSF633)
ds633 = ds633.swap_dims({'obs': 'time'})
ds633 = ds633.chunk({'time': 1000})
ds633 = ds633.sortby('time')

ds634 = xr.open_dataset(TMPSF634)
ds634 = ds634.swap_dims({'obs': 'time'})
ds634 = ds634.chunk({'time': 1000})
ds634 = ds634.sortby('time')

ds635 = xr.open_dataset(TMPSF635)
ds635 = ds635.swap_dims({'obs': 'time'})
ds635 = ds635.chunk({'time': 1000})
ds635 = ds635.sortby('time')

ds636 = xr.open_dataset(TMPSF636)
ds636 = ds636.swap_dims({'obs': 'time'})
ds636 = ds636.chunk({'time': 1000})
ds636 = ds636.sortby('time')

ds637 = xr.open_dataset(TMPSF637)
ds637 = ds637.swap_dims({'obs': 'time'})
ds637 = ds637.chunk({'time': 1000})
ds637 = ds637.sortby('time')

ds638 = xr.open_dataset(TMPSF638)
ds638 = ds638.swap_dims({'obs': 'time'})
ds638 = ds638.chunk({'time': 1000})
ds638 = ds638.sortby('time')

ds639 = xr.open_dataset(TMPSF639)
ds639 = ds639.swap_dims({'obs': 'time'})
ds639 = ds639.chunk({'time': 1000})
ds639 = ds639.sortby('time')

ds640 = xr.open_dataset(TMPSF640)
ds640 = ds640.swap_dims({'obs': 'time'})
ds640 = ds640.chunk({'time': 1000})
ds640 = ds640.sortby('time')

ds641 = xr.open_dataset(TMPSF641)
ds641 = ds641.swap_dims({'obs': 'time'})
ds641 = ds641.chunk({'time': 1000})
ds641 = ds641.sortby('time')

ds642 = xr.open_dataset(TMPSF642)
ds642 = ds642.swap_dims({'obs': 'time'})
ds642 = ds642.chunk({'time': 1000})
ds642 = ds642.sortby('time')

ds643 = xr.open_dataset(TMPSF643)
ds643 = ds643.swap_dims({'obs': 'time'})
ds643 = ds643.chunk({'time': 1000})
ds643 = ds643.sortby('time')

ds644 = xr.open_dataset(TMPSF644)
ds644 = ds644.swap_dims({'obs': 'time'})
ds644 = ds644.chunk({'time': 1000})
ds644 = ds644.sortby('time')

ds645 = xr.open_dataset(TMPSF645)
ds645 = ds645.swap_dims({'obs': 'time'})
ds645 = ds645.chunk({'time': 1000})
ds645 = ds645.sortby('time')

ds646 = xr.open_dataset(TMPSF646)
ds646 = ds646.swap_dims({'obs': 'time'})
ds646 = ds646.chunk({'time': 1000})
ds646 = ds646.sortby('time')

ds647 = xr.open_dataset(TMPSF647)
ds647 = ds647.swap_dims({'obs': 'time'})
ds647 = ds647.chunk({'time': 1000})
ds647 = ds647.sortby('time')

ds648 = xr.open_dataset(TMPSF648)
ds648 = ds648.swap_dims({'obs': 'time'})
ds648 = ds648.chunk({'time': 1000})
ds648 = ds648.sortby('time')

ds649 = xr.open_dataset(TMPSF649)
ds649 = ds649.swap_dims({'obs': 'time'})
ds649 = ds649.chunk({'time': 1000})
ds649 = ds649.sortby('time')

ds650 = xr.open_dataset(TMPSF650)
ds650 = ds650.swap_dims({'obs': 'time'})
ds650 = ds650.chunk({'time': 1000})
ds650 = ds650.sortby('time')

ds651 = xr.open_dataset(TMPSF651)
ds651 = ds651.swap_dims({'obs': 'time'})
ds651 = ds651.chunk({'time': 1000})
ds651 = ds651.sortby('time')

ds652 = xr.open_dataset(TMPSF652)
ds652 = ds652.swap_dims({'obs': 'time'})
ds652 = ds652.chunk({'time': 1000})
ds652 = ds652.sortby('time')

ds653 = xr.open_dataset(TMPSF653)
ds653 = ds653.swap_dims({'obs': 'time'})
ds653 = ds653.chunk({'time': 1000})
ds653 = ds653.sortby('time')

ds654 = xr.open_dataset(TMPSF654)
ds654 = ds654.swap_dims({'obs': 'time'})
ds654 = ds654.chunk({'time': 1000})
ds654 = ds654.sortby('time')

ds655 = xr.open_dataset(TMPSF655)
ds655 = ds655.swap_dims({'obs': 'time'})
ds655 = ds655.chunk({'time': 1000})
ds655 = ds655.sortby('time')

ds656 = xr.open_dataset(TMPSF656)
ds656 = ds656.swap_dims({'obs': 'time'})
ds656 = ds656.chunk({'time': 1000})
ds656 = ds656.sortby('time')

ds657 = xr.open_dataset(TMPSF657)
ds657 = ds657.swap_dims({'obs': 'time'})
ds657 = ds657.chunk({'time': 1000})
ds657 = ds657.sortby('time')

ds658 = xr.open_dataset(TMPSF658)
ds658 = ds658.swap_dims({'obs': 'time'})
ds658 = ds658.chunk({'time': 1000})
ds658 = ds658.sortby('time')

ds659 = xr.open_dataset(TMPSF659)
ds659 = ds659.swap_dims({'obs': 'time'})
ds659 = ds659.chunk({'time': 1000})
ds659 = ds659.sortby('time')

ds660 = xr.open_dataset(TMPSF660)
ds660 = ds660.swap_dims({'obs': 'time'})
ds660 = ds660.chunk({'time': 1000})
ds660 = ds660.sortby('time')

ds661 = xr.open_dataset(TMPSF661)
ds661 = ds661.swap_dims({'obs': 'time'})
ds661 = ds661.chunk({'time': 1000})
ds661 = ds661.sortby('time')

ds662 = xr.open_dataset(TMPSF662)
ds662 = ds662.swap_dims({'obs': 'time'})
ds662 = ds662.chunk({'time': 1000})
ds662 = ds662.sortby('time')

ds663 = xr.open_dataset(TMPSF663)
ds663 = ds663.swap_dims({'obs': 'time'})
ds663 = ds663.chunk({'time': 1000})
ds663 = ds663.sortby('time')

ds664 = xr.open_dataset(TMPSF664)
ds664 = ds664.swap_dims({'obs': 'time'})
ds664 = ds664.chunk({'time': 1000})
ds664 = ds664.sortby('time')

ds665 = xr.open_dataset(TMPSF665)
ds665 = ds665.swap_dims({'obs': 'time'})
ds665 = ds665.chunk({'time': 1000})
ds665 = ds665.sortby('time')

ds666 = xr.open_dataset(TMPSF666)
ds666 = ds666.swap_dims({'obs': 'time'})
ds666 = ds666.chunk({'time': 1000})
ds666 = ds666.sortby('time')

ds667 = xr.open_dataset(TMPSF667)
ds667 = ds667.swap_dims({'obs': 'time'})
ds667 = ds667.chunk({'time': 1000})
ds667 = ds667.sortby('time')

ds668 = xr.open_dataset(TMPSF668)
ds668 = ds668.swap_dims({'obs': 'time'})
ds668 = ds668.chunk({'time': 1000})
ds668 = ds668.sortby('time')

ds669 = xr.open_dataset(TMPSF669)
ds669 = ds669.swap_dims({'obs': 'time'})
ds669 = ds669.chunk({'time': 1000})
ds669 = ds669.sortby('time')

ds670 = xr.open_dataset(TMPSF670)
ds670 = ds670.swap_dims({'obs': 'time'})
ds670 = ds670.chunk({'time': 1000})
ds670 = ds670.sortby('time')

ds671 = xr.open_dataset(TMPSF671)
ds671 = ds671.swap_dims({'obs': 'time'})
ds671 = ds671.chunk({'time': 1000})
ds671 = ds671.sortby('time')

ds672 = xr.open_dataset(TMPSF672)
ds672 = ds672.swap_dims({'obs': 'time'})
ds672 = ds672.chunk({'time': 1000})
ds672 = ds672.sortby('time')

ds673 = xr.open_dataset(TMPSF673)
ds673 = ds673.swap_dims({'obs': 'time'})
ds673 = ds673.chunk({'time': 1000})
ds673 = ds673.sortby('time')

ds674 = xr.open_dataset(TMPSF674)
ds674 = ds674.swap_dims({'obs': 'time'})
ds674 = ds674.chunk({'time': 1000})
ds674 = ds674.sortby('time')

ds675 = xr.open_dataset(TMPSF675)
ds675 = ds675.swap_dims({'obs': 'time'})
ds675 = ds675.chunk({'time': 1000})
ds675 = ds675.sortby('time')

ds676 = xr.open_dataset(TMPSF676)
ds676 = ds676.swap_dims({'obs': 'time'})
ds676 = ds676.chunk({'time': 1000})
ds676 = ds676.sortby('time')

ds677 = xr.open_dataset(TMPSF677)
ds677 = ds677.swap_dims({'obs': 'time'})
ds677 = ds677.chunk({'time': 1000})
ds677 = ds677.sortby('time')

ds678 = xr.open_dataset(TMPSF678)
ds678 = ds678.swap_dims({'obs': 'time'})
ds678 = ds678.chunk({'time': 1000})
ds678 = ds678.sortby('time')

ds679 = xr.open_dataset(TMPSF679)
ds679 = ds679.swap_dims({'obs': 'time'})
ds679 = ds679.chunk({'time': 1000})
ds679 = ds679.sortby('time')

ds680 = xr.open_dataset(TMPSF680)
ds680 = ds680.swap_dims({'obs': 'time'})
ds680 = ds680.chunk({'time': 1000})
ds680 = ds680.sortby('time')

ds681 = xr.open_dataset(TMPSF681)
ds681 = ds681.swap_dims({'obs': 'time'})
ds681 = ds681.chunk({'time': 1000})
ds681 = ds681.sortby('time')

ds682 = xr.open_dataset(TMPSF682)
ds682 = ds682.swap_dims({'obs': 'time'})
ds682 = ds682.chunk({'time': 1000})
ds682 = ds682.sortby('time')

ds683 = xr.open_dataset(TMPSF683)
ds683 = ds683.swap_dims({'obs': 'time'})
ds683 = ds683.chunk({'time': 1000})
ds683 = ds683.sortby('time')

ds684 = xr.open_dataset(TMPSF684)
ds684 = ds684.swap_dims({'obs': 'time'})
ds684 = ds684.chunk({'time': 1000})
ds684 = ds684.sortby('time')

ds685 = xr.open_dataset(TMPSF685)
ds685 = ds685.swap_dims({'obs': 'time'})
ds685 = ds685.chunk({'time': 1000})
ds685 = ds685.sortby('time')

ds686 = xr.open_dataset(TMPSF686)
ds686 = ds686.swap_dims({'obs': 'time'})
ds686 = ds686.chunk({'time': 1000})
ds686 = ds686.sortby('time')

ds687 = xr.open_dataset(TMPSF687)
ds687 = ds687.swap_dims({'obs': 'time'})
ds687 = ds687.chunk({'time': 1000})
ds687 = ds687.sortby('time')

ds688 = xr.open_dataset(TMPSF688)
ds688 = ds688.swap_dims({'obs': 'time'})
ds688 = ds688.chunk({'time': 1000})
ds688 = ds688.sortby('time')

ds689 = xr.open_dataset(TMPSF689)
ds689 = ds689.swap_dims({'obs': 'time'})
ds689 = ds689.chunk({'time': 1000})
ds689 = ds689.sortby('time')

ds690 = xr.open_dataset(TMPSF690)
ds690 = ds690.swap_dims({'obs': 'time'})
ds690 = ds690.chunk({'time': 1000})
ds690 = ds690.sortby('time')

ds691 = xr.open_dataset(TMPSF691)
ds691 = ds691.swap_dims({'obs': 'time'})
ds691 = ds691.chunk({'time': 1000})
ds691 = ds691.sortby('time')

ds692 = xr.open_dataset(TMPSF692)
ds692 = ds692.swap_dims({'obs': 'time'})
ds692 = ds692.chunk({'time': 1000})
ds692 = ds692.sortby('time')

ds693 = xr.open_dataset(TMPSF693)
ds693 = ds693.swap_dims({'obs': 'time'})
ds693 = ds693.chunk({'time': 1000})
ds693 = ds693.sortby('time')

ds694 = xr.open_dataset(TMPSF694)
ds694 = ds694.swap_dims({'obs': 'time'})
ds694 = ds694.chunk({'time': 1000})
ds694 = ds694.sortby('time')

ds695 = xr.open_dataset(TMPSF695)
ds695 = ds695.swap_dims({'obs': 'time'})
ds695 = ds695.chunk({'time': 1000})
ds695 = ds695.sortby('time')

ds696 = xr.open_dataset(TMPSF696)
ds696 = ds696.swap_dims({'obs': 'time'})
ds696 = ds696.chunk({'time': 1000})
ds696 = ds696.sortby('time')

ds697 = xr.open_dataset(TMPSF697)
ds697 = ds697.swap_dims({'obs': 'time'})
ds697 = ds697.chunk({'time': 1000})
ds697 = ds697.sortby('time')

ds698 = xr.open_dataset(TMPSF698)
ds698 = ds698.swap_dims({'obs': 'time'})
ds698 = ds698.chunk({'time': 1000})
ds698 = ds698.sortby('time')

ds699 = xr.open_dataset(TMPSF699)
ds699 = ds699.swap_dims({'obs': 'time'})
ds699 = ds699.chunk({'time': 1000})
ds699 = ds699.sortby('time')

ds700 = xr.open_dataset(TMPSF700)
ds700 = ds700.swap_dims({'obs': 'time'})
ds700 = ds700.chunk({'time': 1000})
ds700 = ds700.sortby('time')

ds701 = xr.open_dataset(TMPSF701)
ds701 = ds701.swap_dims({'obs': 'time'})
ds701 = ds701.chunk({'time': 1000})
ds701 = ds701.sortby('time')

ds702 = xr.open_dataset(TMPSF702)
ds702 = ds702.swap_dims({'obs': 'time'})
ds702 = ds702.chunk({'time': 1000})
ds702 = ds702.sortby('time')

ds703 = xr.open_dataset(TMPSF703)
ds703 = ds703.swap_dims({'obs': 'time'})
ds703 = ds703.chunk({'time': 1000})
ds703 = ds703.sortby('time')

ds704 = xr.open_dataset(TMPSF704)
ds704 = ds704.swap_dims({'obs': 'time'})
ds704 = ds704.chunk({'time': 1000})
ds704 = ds704.sortby('time')

ds705 = xr.open_dataset(TMPSF705)
ds705 = ds705.swap_dims({'obs': 'time'})
ds705 = ds705.chunk({'time': 1000})
ds705 = ds705.sortby('time')

ds706 = xr.open_dataset(TMPSF706)
ds706 = ds706.swap_dims({'obs': 'time'})
ds706 = ds706.chunk({'time': 1000})
ds706 = ds706.sortby('time')

ds707 = xr.open_dataset(TMPSF707)
ds707 = ds707.swap_dims({'obs': 'time'})
ds707 = ds707.chunk({'time': 1000})
ds707 = ds707.sortby('time')

ds708 = xr.open_dataset(TMPSF708)
ds708 = ds708.swap_dims({'obs': 'time'})
ds708 = ds708.chunk({'time': 1000})
ds708 = ds708.sortby('time')

ds709 = xr.open_dataset(TMPSF709)
ds709 = ds709.swap_dims({'obs': 'time'})
ds709 = ds709.chunk({'time': 1000})
ds709 = ds709.sortby('time')

ds710 = xr.open_dataset(TMPSF710)
ds710 = ds710.swap_dims({'obs': 'time'})
ds710 = ds710.chunk({'time': 1000})
ds710 = ds710.sortby('time')

ds711 = xr.open_dataset(TMPSF711)
ds711 = ds711.swap_dims({'obs': 'time'})
ds711 = ds711.chunk({'time': 1000})
ds711 = ds711.sortby('time')

ds712 = xr.open_dataset(TMPSF712)
ds712 = ds712.swap_dims({'obs': 'time'})
ds712 = ds712.chunk({'time': 1000})
ds712 = ds712.sortby('time')

ds713 = xr.open_dataset(TMPSF713)
ds713 = ds713.swap_dims({'obs': 'time'})
ds713 = ds713.chunk({'time': 1000})
ds713 = ds713.sortby('time')

ds714 = xr.open_dataset(TMPSF714)
ds714 = ds714.swap_dims({'obs': 'time'})
ds714 = ds714.chunk({'time': 1000})
ds714 = ds714.sortby('time')

ds715 = xr.open_dataset(TMPSF715)
ds715 = ds715.swap_dims({'obs': 'time'})
ds715 = ds715.chunk({'time': 1000})
ds715 = ds715.sortby('time')

ds716 = xr.open_dataset(TMPSF716)
ds716 = ds716.swap_dims({'obs': 'time'})
ds716 = ds716.chunk({'time': 1000})
ds716 = ds716.sortby('time')

ds717 = xr.open_dataset(TMPSF717)
ds717 = ds717.swap_dims({'obs': 'time'})
ds717 = ds717.chunk({'time': 1000})
ds717 = ds717.sortby('time')

ds718 = xr.open_dataset(TMPSF718)
ds718 = ds718.swap_dims({'obs': 'time'})
ds718 = ds718.chunk({'time': 1000})
ds718 = ds718.sortby('time')

ds719 = xr.open_dataset(TMPSF719)
ds719 = ds719.swap_dims({'obs': 'time'})
ds719 = ds719.chunk({'time': 1000})
ds719 = ds719.sortby('time')

ds720 = xr.open_dataset(TMPSF720)
ds720 = ds720.swap_dims({'obs': 'time'})
ds720 = ds720.chunk({'time': 1000})
ds720 = ds720.sortby('time')

ds721 = xr.open_dataset(TMPSF721)
ds721 = ds721.swap_dims({'obs': 'time'})
ds721 = ds721.chunk({'time': 1000})
ds721 = ds721.sortby('time')

ds722 = xr.open_dataset(TMPSF722)
ds722 = ds722.swap_dims({'obs': 'time'})
ds722 = ds722.chunk({'time': 1000})
ds722 = ds722.sortby('time')

ds723 = xr.open_dataset(TMPSF723)
ds723 = ds723.swap_dims({'obs': 'time'})
ds723 = ds723.chunk({'time': 1000})
ds723 = ds723.sortby('time')

ds724 = xr.open_dataset(TMPSF724)
ds724 = ds724.swap_dims({'obs': 'time'})
ds724 = ds724.chunk({'time': 1000})
ds724 = ds724.sortby('time')

ds725 = xr.open_dataset(TMPSF725)
ds725 = ds725.swap_dims({'obs': 'time'})
ds725 = ds725.chunk({'time': 1000})
ds725 = ds725.sortby('time')

ds726 = xr.open_dataset(TMPSF726)
ds726 = ds726.swap_dims({'obs': 'time'})
ds726 = ds726.chunk({'time': 1000})
ds726 = ds726.sortby('time')

ds727 = xr.open_dataset(TMPSF727)
ds727 = ds727.swap_dims({'obs': 'time'})
ds727 = ds727.chunk({'time': 1000})
ds727 = ds727.sortby('time')

ds728 = xr.open_dataset(TMPSF728)
ds728 = ds728.swap_dims({'obs': 'time'})
ds728 = ds728.chunk({'time': 1000})
ds728 = ds728.sortby('time')

ds729 = xr.open_dataset(TMPSF729)
ds729 = ds729.swap_dims({'obs': 'time'})
ds729 = ds729.chunk({'time': 1000})
ds729 = ds729.sortby('time')

ds730 = xr.open_dataset(TMPSF730)
ds730 = ds730.swap_dims({'obs': 'time'})
ds730 = ds730.chunk({'time': 1000})
ds730 = ds730.sortby('time')

ds731 = xr.open_dataset(TMPSF731)
ds731 = ds731.swap_dims({'obs': 'time'})
ds731 = ds731.chunk({'time': 1000})
ds731 = ds731.sortby('time')

ds732 = xr.open_dataset(TMPSF732)
ds732 = ds732.swap_dims({'obs': 'time'})
ds732 = ds732.chunk({'time': 1000})
ds732 = ds732.sortby('time')

ds733 = xr.open_dataset(TMPSF733)
ds733 = ds733.swap_dims({'obs': 'time'})
ds733 = ds733.chunk({'time': 1000})
ds733 = ds733.sortby('time')

ds734 = xr.open_dataset(TMPSF734)
ds734 = ds734.swap_dims({'obs': 'time'})
ds734 = ds734.chunk({'time': 1000})
ds734 = ds734.sortby('time')

ds735 = xr.open_dataset(TMPSF735)
ds735 = ds735.swap_dims({'obs': 'time'})
ds735 = ds735.chunk({'time': 1000})
ds735 = ds735.sortby('time')

ds736 = xr.open_dataset(TMPSF736)
ds736 = ds736.swap_dims({'obs': 'time'})
ds736 = ds736.chunk({'time': 1000})
ds736 = ds736.sortby('time')

ds737 = xr.open_dataset(TMPSF737)
ds737 = ds737.swap_dims({'obs': 'time'})
ds737 = ds737.chunk({'time': 1000})
ds737 = ds737.sortby('time')

ds738 = xr.open_dataset(TMPSF738)
ds738 = ds738.swap_dims({'obs': 'time'})
ds738 = ds738.chunk({'time': 1000})
ds738 = ds738.sortby('time')

ds739 = xr.open_dataset(TMPSF739)
ds739 = ds739.swap_dims({'obs': 'time'})
ds739 = ds739.chunk({'time': 1000})
ds739 = ds739.sortby('time')

ds740 = xr.open_dataset(TMPSF740)
ds740 = ds740.swap_dims({'obs': 'time'})
ds740 = ds740.chunk({'time': 1000})
ds740 = ds740.sortby('time')

ds741 = xr.open_dataset(TMPSF741)
ds741 = ds741.swap_dims({'obs': 'time'})
ds741 = ds741.chunk({'time': 1000})
ds741 = ds741.sortby('time')

ds742 = xr.open_dataset(TMPSF742)
ds742 = ds742.swap_dims({'obs': 'time'})
ds742 = ds742.chunk({'time': 1000})
ds742 = ds742.sortby('time')

ds743 = xr.open_dataset(TMPSF743)
ds743 = ds743.swap_dims({'obs': 'time'})
ds743 = ds743.chunk({'time': 1000})
ds743 = ds743.sortby('time')

ds744 = xr.open_dataset(TMPSF744)
ds744 = ds744.swap_dims({'obs': 'time'})
ds744 = ds744.chunk({'time': 1000})
ds744 = ds744.sortby('time')

ds745 = xr.open_dataset(TMPSF745)
ds745 = ds745.swap_dims({'obs': 'time'})
ds745 = ds745.chunk({'time': 1000})
ds745 = ds745.sortby('time')

ds746 = xr.open_dataset(TMPSF746)
ds746 = ds746.swap_dims({'obs': 'time'})
ds746 = ds746.chunk({'time': 1000})
ds746 = ds746.sortby('time')

ds747 = xr.open_dataset(TMPSF747)
ds747 = ds747.swap_dims({'obs': 'time'})
ds747 = ds747.chunk({'time': 1000})
ds747 = ds747.sortby('time')

ds748 = xr.open_dataset(TMPSF748)
ds748 = ds748.swap_dims({'obs': 'time'})
ds748 = ds748.chunk({'time': 1000})
ds748 = ds748.sortby('time')

ds749 = xr.open_dataset(TMPSF749)
ds749 = ds749.swap_dims({'obs': 'time'})
ds749 = ds749.chunk({'time': 1000})
ds749 = ds749.sortby('time')

ds750 = xr.open_dataset(TMPSF750)
ds750 = ds750.swap_dims({'obs': 'time'})
ds750 = ds750.chunk({'time': 1000})
ds750 = ds750.sortby('time')

ds751 = xr.open_dataset(TMPSF751)
ds751 = ds751.swap_dims({'obs': 'time'})
ds751 = ds751.chunk({'time': 1000})
ds751 = ds751.sortby('time')

ds752 = xr.open_dataset(TMPSF752)
ds752 = ds752.swap_dims({'obs': 'time'})
ds752 = ds752.chunk({'time': 1000})
ds752 = ds752.sortby('time')

ds753 = xr.open_dataset(TMPSF753)
ds753 = ds753.swap_dims({'obs': 'time'})
ds753 = ds753.chunk({'time': 1000})
ds753 = ds753.sortby('time')

ds754 = xr.open_dataset(TMPSF754)
ds754 = ds754.swap_dims({'obs': 'time'})
ds754 = ds754.chunk({'time': 1000})
ds754 = ds754.sortby('time')

ds755 = xr.open_dataset(TMPSF755)
ds755 = ds755.swap_dims({'obs': 'time'})
ds755 = ds755.chunk({'time': 1000})
ds755 = ds755.sortby('time')

ds756 = xr.open_dataset(TMPSF756)
ds756 = ds756.swap_dims({'obs': 'time'})
ds756 = ds756.chunk({'time': 1000})
ds756 = ds756.sortby('time')

ds757 = xr.open_dataset(TMPSF757)
ds757 = ds757.swap_dims({'obs': 'time'})
ds757 = ds757.chunk({'time': 1000})
ds757 = ds757.sortby('time')

ds758 = xr.open_dataset(TMPSF758)
ds758 = ds758.swap_dims({'obs': 'time'})
ds758 = ds758.chunk({'time': 1000})
ds758 = ds758.sortby('time')

ds759 = xr.open_dataset(TMPSF759)
ds759 = ds759.swap_dims({'obs': 'time'})
ds759 = ds759.chunk({'time': 1000})
ds759 = ds759.sortby('time')

ds760 = xr.open_dataset(TMPSF760)
ds760 = ds760.swap_dims({'obs': 'time'})
ds760 = ds760.chunk({'time': 1000})
ds760 = ds760.sortby('time')

ds761 = xr.open_dataset(TMPSF761)
ds761 = ds761.swap_dims({'obs': 'time'})
ds761 = ds761.chunk({'time': 1000})
ds761 = ds761.sortby('time')

ds762 = xr.open_dataset(TMPSF762)
ds762 = ds762.swap_dims({'obs': 'time'})
ds762 = ds762.chunk({'time': 1000})
ds762 = ds762.sortby('time')

ds763 = xr.open_dataset(TMPSF763)
ds763 = ds763.swap_dims({'obs': 'time'})
ds763 = ds763.chunk({'time': 1000})
ds763 = ds763.sortby('time')

ds764 = xr.open_dataset(TMPSF764)
ds764 = ds764.swap_dims({'obs': 'time'})
ds764 = ds764.chunk({'time': 1000})
ds764 = ds764.sortby('time')

ds765 = xr.open_dataset(TMPSF765)
ds765 = ds765.swap_dims({'obs': 'time'})
ds765 = ds765.chunk({'time': 1000})
ds765 = ds765.sortby('time')

ds766 = xr.open_dataset(TMPSF766)
ds766 = ds766.swap_dims({'obs': 'time'})
ds766 = ds766.chunk({'time': 1000})
ds766 = ds766.sortby('time')

ds767 = xr.open_dataset(TMPSF767)
ds767 = ds767.swap_dims({'obs': 'time'})
ds767 = ds767.chunk({'time': 1000})
ds767 = ds767.sortby('time')

ds768 = xr.open_dataset(TMPSF768)
ds768 = ds768.swap_dims({'obs': 'time'})
ds768 = ds768.chunk({'time': 1000})
ds768 = ds768.sortby('time')

ds769 = xr.open_dataset(TMPSF769)
ds769 = ds769.swap_dims({'obs': 'time'})
ds769 = ds769.chunk({'time': 1000})
ds769 = ds769.sortby('time')

ds770 = xr.open_dataset(TMPSF770)
ds770 = ds770.swap_dims({'obs': 'time'})
ds770 = ds770.chunk({'time': 1000})
ds770 = ds770.sortby('time')

ds771 = xr.open_dataset(TMPSF771)
ds771 = ds771.swap_dims({'obs': 'time'})
ds771 = ds771.chunk({'time': 1000})
ds771 = ds771.sortby('time')

ds772 = xr.open_dataset(TMPSF772)
ds772 = ds772.swap_dims({'obs': 'time'})
ds772 = ds772.chunk({'time': 1000})
ds772 = ds772.sortby('time')

ds773 = xr.open_dataset(TMPSF773)
ds773 = ds773.swap_dims({'obs': 'time'})
ds773 = ds773.chunk({'time': 1000})
ds773 = ds773.sortby('time')

ds774 = xr.open_dataset(TMPSF774)
ds774 = ds774.swap_dims({'obs': 'time'})
ds774 = ds774.chunk({'time': 1000})
ds774 = ds774.sortby('time')

ds775 = xr.open_dataset(TMPSF775)
ds775 = ds775.swap_dims({'obs': 'time'})
ds775 = ds775.chunk({'time': 1000})
ds775 = ds775.sortby('time')

ds776 = xr.open_dataset(TMPSF776)
ds776 = ds776.swap_dims({'obs': 'time'})
ds776 = ds776.chunk({'time': 1000})
ds776 = ds776.sortby('time')

ds777 = xr.open_dataset(TMPSF777)
ds777 = ds777.swap_dims({'obs': 'time'})
ds777 = ds777.chunk({'time': 1000})
ds777 = ds777.sortby('time')

ds778 = xr.open_dataset(TMPSF778)
ds778 = ds778.swap_dims({'obs': 'time'})
ds778 = ds778.chunk({'time': 1000})
ds778 = ds778.sortby('time')

ds779 = xr.open_dataset(TMPSF779)
ds779 = ds779.swap_dims({'obs': 'time'})
ds779 = ds779.chunk({'time': 1000})
ds779 = ds779.sortby('time')

ds780 = xr.open_dataset(TMPSF780)
ds780 = ds780.swap_dims({'obs': 'time'})
ds780 = ds780.chunk({'time': 1000})
ds780 = ds780.sortby('time')

ds781 = xr.open_dataset(TMPSF781)
ds781 = ds781.swap_dims({'obs': 'time'})
ds781 = ds781.chunk({'time': 1000})
ds781 = ds781.sortby('time')

ds782 = xr.open_dataset(TMPSF782)
ds782 = ds782.swap_dims({'obs': 'time'})
ds782 = ds782.chunk({'time': 1000})
ds782 = ds782.sortby('time')

ds783 = xr.open_dataset(TMPSF783)
ds783 = ds783.swap_dims({'obs': 'time'})
ds783 = ds783.chunk({'time': 1000})
ds783 = ds783.sortby('time')

ds784 = xr.open_dataset(TMPSF784)
ds784 = ds784.swap_dims({'obs': 'time'})
ds784 = ds784.chunk({'time': 1000})
ds784 = ds784.sortby('time')

ds785 = xr.open_dataset(TMPSF785)
ds785 = ds785.swap_dims({'obs': 'time'})
ds785 = ds785.chunk({'time': 1000})
ds785 = ds785.sortby('time')

ds786 = xr.open_dataset(TMPSF786)
ds786 = ds786.swap_dims({'obs': 'time'})
ds786 = ds786.chunk({'time': 1000})
ds786 = ds786.sortby('time')

ds787 = xr.open_dataset(TMPSF787)
ds787 = ds787.swap_dims({'obs': 'time'})
ds787 = ds787.chunk({'time': 1000})
ds787 = ds787.sortby('time')

ds788 = xr.open_dataset(TMPSF788)
ds788 = ds788.swap_dims({'obs': 'time'})
ds788 = ds788.chunk({'time': 1000})
ds788 = ds788.sortby('time')

ds789 = xr.open_dataset(TMPSF789)
ds789 = ds789.swap_dims({'obs': 'time'})
ds789 = ds789.chunk({'time': 1000})
ds789 = ds789.sortby('time')

ds790 = xr.open_dataset(TMPSF790)
ds790 = ds790.swap_dims({'obs': 'time'})
ds790 = ds790.chunk({'time': 1000})
ds790 = ds790.sortby('time')

ds791 = xr.open_dataset(TMPSF791)
ds791 = ds791.swap_dims({'obs': 'time'})
ds791 = ds791.chunk({'time': 1000})
ds791 = ds791.sortby('time')

ds792 = xr.open_dataset(TMPSF792)
ds792 = ds792.swap_dims({'obs': 'time'})
ds792 = ds792.chunk({'time': 1000})
ds792 = ds792.sortby('time')

ds793 = xr.open_dataset(TMPSF793)
ds793 = ds793.swap_dims({'obs': 'time'})
ds793 = ds793.chunk({'time': 1000})
ds793 = ds793.sortby('time')

ds794 = xr.open_dataset(TMPSF794)
ds794 = ds794.swap_dims({'obs': 'time'})
ds794 = ds794.chunk({'time': 1000})
ds794 = ds794.sortby('time')

ds795 = xr.open_dataset(TMPSF795)
ds795 = ds795.swap_dims({'obs': 'time'})
ds795 = ds795.chunk({'time': 1000})
ds795 = ds795.sortby('time')

ds796 = xr.open_dataset(TMPSF796)
ds796 = ds796.swap_dims({'obs': 'time'})
ds796 = ds796.chunk({'time': 1000})
ds796 = ds796.sortby('time')

ds797 = xr.open_dataset(TMPSF797)
ds797 = ds797.swap_dims({'obs': 'time'})
ds797 = ds797.chunk({'time': 1000})
ds797 = ds797.sortby('time')

ds798 = xr.open_dataset(TMPSF798)
ds798 = ds798.swap_dims({'obs': 'time'})
ds798 = ds798.chunk({'time': 1000})
ds798 = ds798.sortby('time')

ds799 = xr.open_dataset(TMPSF799)
ds799 = ds799.swap_dims({'obs': 'time'})
ds799 = ds799.chunk({'time': 1000})
ds799 = ds799.sortby('time')

ds800 = xr.open_dataset(TMPSF800)
ds800 = ds800.swap_dims({'obs': 'time'})
ds800 = ds800.chunk({'time': 1000})
ds800 = ds800.sortby('time')

ds801 = xr.open_dataset(TMPSF801)
ds801 = ds801.swap_dims({'obs': 'time'})
ds801 = ds801.chunk({'time': 1000})
ds801 = ds801.sortby('time')

ds802 = xr.open_dataset(TMPSF802)
ds802 = ds802.swap_dims({'obs': 'time'})
ds802 = ds802.chunk({'time': 1000})
ds802 = ds802.sortby('time')

ds803 = xr.open_dataset(TMPSF803)
ds803 = ds803.swap_dims({'obs': 'time'})
ds803 = ds803.chunk({'time': 1000})
ds803 = ds803.sortby('time')

ds804 = xr.open_dataset(TMPSF804)
ds804 = ds804.swap_dims({'obs': 'time'})
ds804 = ds804.chunk({'time': 1000})
ds804 = ds804.sortby('time')

ds805 = xr.open_dataset(TMPSF805)
ds805 = ds805.swap_dims({'obs': 'time'})
ds805 = ds805.chunk({'time': 1000})
ds805 = ds805.sortby('time')

ds806 = xr.open_dataset(TMPSF806)
ds806 = ds806.swap_dims({'obs': 'time'})
ds806 = ds806.chunk({'time': 1000})
ds806 = ds806.sortby('time')

ds807 = xr.open_dataset(TMPSF807)
ds807 = ds807.swap_dims({'obs': 'time'})
ds807 = ds807.chunk({'time': 1000})
ds807 = ds807.sortby('time')

ds808 = xr.open_dataset(TMPSF808)
ds808 = ds808.swap_dims({'obs': 'time'})
ds808 = ds808.chunk({'time': 1000})
ds808 = ds808.sortby('time')

ds809 = xr.open_dataset(TMPSF809)
ds809 = ds809.swap_dims({'obs': 'time'})
ds809 = ds809.chunk({'time': 1000})
ds809 = ds809.sortby('time')

ds810 = xr.open_dataset(TMPSF810)
ds810 = ds810.swap_dims({'obs': 'time'})
ds810 = ds810.chunk({'time': 1000})
ds810 = ds810.sortby('time')

ds811 = xr.open_dataset(TMPSF811)
ds811 = ds811.swap_dims({'obs': 'time'})
ds811 = ds811.chunk({'time': 1000})
ds811 = ds811.sortby('time')

ds812 = xr.open_dataset(TMPSF812)
ds812 = ds812.swap_dims({'obs': 'time'})
ds812 = ds812.chunk({'time': 1000})
ds812 = ds812.sortby('time')

ds813 = xr.open_dataset(TMPSF813)
ds813 = ds813.swap_dims({'obs': 'time'})
ds813 = ds813.chunk({'time': 1000})
ds813 = ds813.sortby('time')

ds814 = xr.open_dataset(TMPSF814)
ds814 = ds814.swap_dims({'obs': 'time'})
ds814 = ds814.chunk({'time': 1000})
ds814 = ds814.sortby('time')

ds815 = xr.open_dataset(TMPSF815)
ds815 = ds815.swap_dims({'obs': 'time'})
ds815 = ds815.chunk({'time': 1000})
ds815 = ds815.sortby('time')

ds816 = xr.open_dataset(TMPSF816)
ds816 = ds816.swap_dims({'obs': 'time'})
ds816 = ds816.chunk({'time': 1000})
ds816 = ds816.sortby('time')

ds817 = xr.open_dataset(TMPSF817)
ds817 = ds817.swap_dims({'obs': 'time'})
ds817 = ds817.chunk({'time': 1000})
ds817 = ds817.sortby('time')

ds818 = xr.open_dataset(TMPSF818)
ds818 = ds818.swap_dims({'obs': 'time'})
ds818 = ds818.chunk({'time': 1000})
ds818 = ds818.sortby('time')

ds819 = xr.open_dataset(TMPSF819)
ds819 = ds819.swap_dims({'obs': 'time'})
ds819 = ds819.chunk({'time': 1000})
ds819 = ds819.sortby('time')

ds820 = xr.open_dataset(TMPSF820)
ds820 = ds820.swap_dims({'obs': 'time'})
ds820 = ds820.chunk({'time': 1000})
ds820 = ds820.sortby('time')

ds821 = xr.open_dataset(TMPSF821)
ds821 = ds821.swap_dims({'obs': 'time'})
ds821 = ds821.chunk({'time': 1000})
ds821 = ds821.sortby('time')

ds822 = xr.open_dataset(TMPSF822)
ds822 = ds822.swap_dims({'obs': 'time'})
ds822 = ds822.chunk({'time': 1000})
ds822 = ds822.sortby('time')

ds823 = xr.open_dataset(TMPSF823)
ds823 = ds823.swap_dims({'obs': 'time'})
ds823 = ds823.chunk({'time': 1000})
ds823 = ds823.sortby('time')

ds824 = xr.open_dataset(TMPSF824)
ds824 = ds824.swap_dims({'obs': 'time'})
ds824 = ds824.chunk({'time': 1000})
ds824 = ds824.sortby('time')

ds825 = xr.open_dataset(TMPSF825)
ds825 = ds825.swap_dims({'obs': 'time'})
ds825 = ds825.chunk({'time': 1000})
ds825 = ds825.sortby('time')

ds826 = xr.open_dataset(TMPSF826)
ds826 = ds826.swap_dims({'obs': 'time'})
ds826 = ds826.chunk({'time': 1000})
ds826 = ds826.sortby('time')

ds827 = xr.open_dataset(TMPSF827)
ds827 = ds827.swap_dims({'obs': 'time'})
ds827 = ds827.chunk({'time': 1000})
ds827 = ds827.sortby('time')

ds828 = xr.open_dataset(TMPSF828)
ds828 = ds828.swap_dims({'obs': 'time'})
ds828 = ds828.chunk({'time': 1000})
ds828 = ds828.sortby('time')

ds829 = xr.open_dataset(TMPSF829)
ds829 = ds829.swap_dims({'obs': 'time'})
ds829 = ds829.chunk({'time': 1000})
ds829 = ds829.sortby('time')

ds830 = xr.open_dataset(TMPSF830)
ds830 = ds830.swap_dims({'obs': 'time'})
ds830 = ds830.chunk({'time': 1000})
ds830 = ds830.sortby('time')

ds831 = xr.open_dataset(TMPSF831)
ds831 = ds831.swap_dims({'obs': 'time'})
ds831 = ds831.chunk({'time': 1000})
ds831 = ds831.sortby('time')

ds832 = xr.open_dataset(TMPSF832)
ds832 = ds832.swap_dims({'obs': 'time'})
ds832 = ds832.chunk({'time': 1000})
ds832 = ds832.sortby('time')

ds833 = xr.open_dataset(TMPSF833)
ds833 = ds833.swap_dims({'obs': 'time'})
ds833 = ds833.chunk({'time': 1000})
ds833 = ds833.sortby('time')

ds834 = xr.open_dataset(TMPSF834)
ds834 = ds834.swap_dims({'obs': 'time'})
ds834 = ds834.chunk({'time': 1000})
ds834 = ds834.sortby('time')

ds835 = xr.open_dataset(TMPSF835)
ds835 = ds835.swap_dims({'obs': 'time'})
ds835 = ds835.chunk({'time': 1000})
ds835 = ds835.sortby('time')

ds836 = xr.open_dataset(TMPSF836)
ds836 = ds836.swap_dims({'obs': 'time'})
ds836 = ds836.chunk({'time': 1000})
ds836 = ds836.sortby('time')

ds837 = xr.open_dataset(TMPSF837)
ds837 = ds837.swap_dims({'obs': 'time'})
ds837 = ds837.chunk({'time': 1000})
ds837 = ds837.sortby('time')

ds838 = xr.open_dataset(TMPSF838)
ds838 = ds838.swap_dims({'obs': 'time'})
ds838 = ds838.chunk({'time': 1000})
ds838 = ds838.sortby('time')

ds839 = xr.open_dataset(TMPSF839)
ds839 = ds839.swap_dims({'obs': 'time'})
ds839 = ds839.chunk({'time': 1000})
ds839 = ds839.sortby('time')

ds840 = xr.open_dataset(TMPSF840)
ds840 = ds840.swap_dims({'obs': 'time'})
ds840 = ds840.chunk({'time': 1000})
ds840 = ds840.sortby('time')

ds841 = xr.open_dataset(TMPSF841)
ds841 = ds841.swap_dims({'obs': 'time'})
ds841 = ds841.chunk({'time': 1000})
ds841 = ds841.sortby('time')

ds842 = xr.open_dataset(TMPSF842)
ds842 = ds842.swap_dims({'obs': 'time'})
ds842 = ds842.chunk({'time': 1000})
ds842 = ds842.sortby('time')

ds843 = xr.open_dataset(TMPSF843)
ds843 = ds843.swap_dims({'obs': 'time'})
ds843 = ds843.chunk({'time': 1000})
ds843 = ds843.sortby('time')

ds844 = xr.open_dataset(TMPSF844)
ds844 = ds844.swap_dims({'obs': 'time'})
ds844 = ds844.chunk({'time': 1000})
ds844 = ds844.sortby('time')

ds845 = xr.open_dataset(TMPSF845)
ds845 = ds845.swap_dims({'obs': 'time'})
ds845 = ds845.chunk({'time': 1000})
ds845 = ds845.sortby('time')

ds846 = xr.open_dataset(TMPSF846)
ds846 = ds846.swap_dims({'obs': 'time'})
ds846 = ds846.chunk({'time': 1000})
ds846 = ds846.sortby('time')

ds847 = xr.open_dataset(TMPSF847)
ds847 = ds847.swap_dims({'obs': 'time'})
ds847 = ds847.chunk({'time': 1000})
ds847 = ds847.sortby('time')

ds848 = xr.open_dataset(TMPSF848)
ds848 = ds848.swap_dims({'obs': 'time'})
ds848 = ds848.chunk({'time': 1000})
ds848 = ds848.sortby('time')

ds849 = xr.open_dataset(TMPSF849)
ds849 = ds849.swap_dims({'obs': 'time'})
ds849 = ds849.chunk({'time': 1000})
ds849 = ds849.sortby('time')

ds850 = xr.open_dataset(TMPSF850)
ds850 = ds850.swap_dims({'obs': 'time'})
ds850 = ds850.chunk({'time': 1000})
ds850 = ds850.sortby('time')

ds851 = xr.open_dataset(TMPSF851)
ds851 = ds851.swap_dims({'obs': 'time'})
ds851 = ds851.chunk({'time': 1000})
ds851 = ds851.sortby('time')

ds852 = xr.open_dataset(TMPSF852)
ds852 = ds852.swap_dims({'obs': 'time'})
ds852 = ds852.chunk({'time': 1000})
ds852 = ds852.sortby('time')

ds853 = xr.open_dataset(TMPSF853)
ds853 = ds853.swap_dims({'obs': 'time'})
ds853 = ds853.chunk({'time': 1000})
ds853 = ds853.sortby('time')

# %%
combined = xr.concat([
    ds369, ds370, ds371, ds372, ds373, ds374, ds375, ds376, ds377, ds378, ds379, ds380, ds381, ds382, ds383, ds384, 
    ds385, ds386, ds387, ds388, ds389, ds390, ds391, ds392, ds393, ds394, ds395, ds396, ds397, ds398, ds399, ds400, 
    ds401, ds402, ds403, ds404, ds405, ds406, ds407, ds408, ds409, ds410, ds411, ds412, ds413, ds414, ds415, ds416, 
    ds417, ds418, ds419, ds420, ds421, ds422, ds423, ds424, ds425, ds426, ds427, ds428, ds429, ds430, ds431, ds432, 
    ds433, ds434, ds435, ds436, ds437, ds438, ds439, ds440, ds441, ds442, ds443, ds444, ds445, ds446, ds447, ds448, 
    ds449, ds450, ds451, ds452, ds453, ds454, ds455, ds456, ds457, ds458, ds459, ds460, ds461, ds462, ds463, ds464, 
    ds465, ds466, ds467, ds468, ds469, ds470, ds471, ds472, ds473, ds474, ds475, ds476, ds477, ds478, ds479, ds480, 
    ds481, ds482, ds483, ds484, ds485, ds486, ds487, ds488, ds489, ds490, ds491, ds492, ds493, ds494, ds495, ds496, 
    ds497, ds498, ds499, ds500, ds501, ds502, ds503, ds504, ds505, ds506, ds507, ds508, ds509, ds510, ds511, ds512, 
    ds513, ds514, ds515, ds516, ds517, ds518, ds519, ds520, ds521, ds522, ds523, ds524, ds525, ds526, ds527, ds528, 
    ds529, ds530, ds531, ds532, ds533, ds534, ds535, ds536, ds537, ds538, ds539, ds540, ds541, ds542, ds543, ds544, 
    ds545, ds546, ds547, ds548, ds549, ds550, ds551, ds552, ds553, ds554, ds555, ds556, ds557, ds558, ds559, ds560, 
    ds561, ds562, ds563, ds564, ds565, ds566, ds567, ds568, ds569, ds570, ds571, ds572, ds573, ds574, ds575, ds576, 
    ds577, ds578, ds579, ds580, ds581, ds582, ds583, ds584, ds585, ds586, ds587, ds588, ds589, ds590, ds591, ds592, 
    ds593, ds594, ds595, ds596, ds597, ds598, ds599, ds600, ds601, ds602, ds603, ds604, ds605, ds606, ds607, ds608, 
    ds609, ds610, ds611, ds612, ds613, ds614, ds615, ds616, ds617, ds618, ds619, ds620, ds621, ds622, ds623, ds624, 
    ds625, ds626, ds627, ds628, ds629, ds630, ds631, ds632, ds633, ds634, ds635, ds636, ds637, ds638, ds639, ds640, 
    ds641, ds642, ds643, ds644, ds645, ds646, ds647, ds648, ds649, ds650, ds651, ds652, ds653, ds654, ds655, ds656, 
    ds657, ds658, ds659, ds660, ds661, ds662, ds663, ds664, ds665, ds666, ds667, ds668, ds669, ds670, ds671, ds672, 
    ds673, ds674, ds675, ds676, ds677, ds678, ds679, ds680, ds681, ds682, ds683, ds684, ds685, ds686, ds687, ds688, 
    ds689, ds690, ds691, ds692, ds693, ds694, ds695, ds696, ds697, ds698, ds699, ds700, ds701, ds702, ds703, ds704, 
    ds705, ds706, ds707, ds708, ds709, ds710, ds711, ds712, ds713, ds714, ds715, ds716, ds717, ds718, ds719, ds720, 
    ds721, ds722, ds723, ds724, ds725, ds726, ds727, ds728, ds729, ds730, ds731, ds732, ds733, ds734, ds735, ds736, 
    ds737, ds738, ds739, ds740, ds741, ds742, ds743, ds744, ds745, ds746, ds747, ds748, ds749, ds750, ds751, ds752, 
    ds753, ds754, ds755, ds756, ds757, ds758, ds759, ds760, ds761, ds762, ds763, ds764, ds765, ds766, ds767, ds768, 
    ds769, ds770, ds771, ds772, ds773, ds774, ds775, ds776, ds777, ds778, ds779, ds780, ds781, ds782, ds783, ds784, 
    ds785, ds786, ds787, ds788, ds789, ds790, ds791, ds792, ds793, ds794, ds795, ds796, ds797, ds798, ds799, ds800, 
    ds801, ds802, ds803, ds804, ds805, ds806, ds807, ds808, ds809, ds810, ds811, ds812, ds813, ds814, ds815, ds816, 
    ds817, ds818, ds819, ds820, ds821, ds822, ds823, ds824, ds825, ds826, ds827, ds828, ds829, ds830, ds831, ds832, 
    ds833, ds834, ds835, ds836, ds837, ds838, ds839, ds840, ds841, ds842, ds843, ds844, ds845, ds846, ds847, ds848, 
    ds849, ds850, ds851, ds852, ds853
], dim='time')

# %%
axial_tmpsf = combined[['time', 'temperature01', 'temperature02', 'temperature03','temperature04','temperature05','temperature06','temperature07','temperature08','temperature09','temperature10','temperature11','temperature12','temperature13','temperature14','temperature15','temperature16','temperature17','temperature18','temperature19','temperature20','temperature21','temperature22','temperature23','temperature24']].to_pandas()
axial_tmpsf.head(5)
# Out:
#                                temperature01  temperature02  temperature03  \
# time
# 2023-10-01 07:33:41.326207488         2.4877         2.4713         2.4789
# 2023-10-01 07:33:51.325726720         2.4867         2.4741         2.4776
# 2023-10-01 07:34:01.324900864         2.4858         2.4792         2.4777
# 2023-10-01 07:34:11.327609344         2.4861         2.4888         2.4837
# 2023-10-01 07:34:21.326031872         2.4879         2.4970         2.4880
#
#                                temperature04  temperature05  temperature06  \
# time
# 2023-10-01 07:33:41.326207488         2.4984         2.5659         2.5871
# 2023-10-01 07:33:51.325726720         2.4978         2.5640         2.5869
# 2023-10-01 07:34:01.324900864         2.4989         2.5659         2.5940
# 2023-10-01 07:34:11.327609344         2.4977         2.5655         2.6010
# 2023-10-01 07:34:21.326031872         2.4949         2.5637         2.6068
#
# ...

# %%
axial_tmpsf.rename(columns={'temperature01':'t01','temperature02':'t02', 'temperature03':'t03'
                         ,'temperature04':'t04','temperature05':'t05','temperature06':'t06'
                         ,'temperature07':'t07','temperature08':'t08','temperature09':'t09'
                         ,'temperature10':'t10','temperature11':'t11','temperature12':'t12'
                         ,'temperature13':'t13','temperature14':'t14','temperature15':'t15'
                         ,'temperature16':'t16','temperature17':'t17','temperature18':'t18'
                         ,'temperature19':'t19','temperature20':'t20','temperature21':'t21'
                         ,'temperature22':'t22','temperature23':'t23','temperature24':'t24'}, inplace=True)
axial_tmpsf.index=pd.to_datetime(axial_tmpsf.index)
axial_tmpsf = axial_tmpsf.drop_duplicates(keep='first', inplace=False, ignore_index=False)
axial_tmpsf['tl1'] = axial_tmpsf[['t01', 't02', 't03', 't04', 't05', 't06', 't07']].mean(axis=1)
axial_tmpsf['tl2'] = axial_tmpsf[['t08', 't09', 't10', 't11', 't12', 't13', 't14']].mean(axis=1)
axial_tmpsf['tl3'] = axial_tmpsf[['t15', 't16', 't17', 't18', 't19', 't20', 't21']].mean(axis=1)
axial_tmpsf['tl4'] = axial_tmpsf[['t22', 't23', 't24']].mean(axis=1)
axial_tmpsf.head(5)
# Out:
#                                   t01     t02     t03     t04     t05     t06  \
# time
# 2023-10-01 07:33:41.326207488  2.4877  2.4713  2.4789  2.4984  2.5659  2.5871
# 2023-10-01 07:33:51.325726720  2.4867  2.4741  2.4776  2.4978  2.5640  2.5869
# 2023-10-01 07:34:01.324900864  2.4858  2.4792  2.4777  2.4989  2.5659  2.5940
# 2023-10-01 07:34:11.327609344  2.4861  2.4888  2.4837  2.4977  2.5655  2.6010
# 2023-10-01 07:34:21.326031872  2.4879  2.4970  2.4880  2.4949  2.5637  2.6068
#
#                                   t07     t08     t09     t10  ...     t20  \
# time                                                           ...
# 2023-10-01 07:33:41.326207488  2.5712  2.4554  2.4722  2.4684  ...  2.4435
# 2023-10-01 07:33:51.325726720  2.5699  2.4553  2.4704  2.4665  ...  2.4435
# 2023-10-01 07:34:01.324900864  2.5685  2.4548  2.4681  2.4654  ...  2.4435
# 2023-10-01 07:34:11.327609344  2.5672  2.4562  2.4697  2.4644  ...  2.4450
# ...

# %%
axial_tmpsf_sub=axial_tmpsf.loc[:,['tl1','tl2','tl3','tl4']]
axial_tmpsf_sub.head(5)
# Out:
#                                     tl1       tl2       tl3       tl4
# time
# 2023-10-01 07:33:41.326207488  2.522928  2.463643  2.449500  2.441334
# 2023-10-01 07:33:51.325726720  2.522429  2.462528  2.450386  2.440634
# 2023-10-01 07:34:01.324900864  2.524286  2.462343  2.451857  2.439433
# 2023-10-01 07:34:11.327609344  2.527143  2.463528  2.454714  2.438033
# 2023-10-01 07:34:21.326031872  2.529228  2.466143  2.456400  2.435833

# %%
resampledaxial = axial_tmpsf_sub.resample('d').median()
display(resampledaxial)
# Out:
#                  tl1       tl2       tl3       tl4
# time
# 2023-10-01  2.614664  2.513229  2.479693  2.463400
# 2023-10-02  2.730614  2.551043  2.464543  2.434667
# 2023-10-03  2.701572  2.528343  2.468000  2.440867
# 2023-10-04  2.683372  2.528257  2.474628  2.452400
# 2023-10-05  2.726600  2.501900  2.442343  2.428000
# ...              ...       ...       ...       ...
# 2025-02-24  2.828357  2.758243  2.730343  2.716133
# 2025-02-25  2.775714  2.693986  2.664272  2.678766
# 2025-02-26  2.837086  2.758500  2.718957  2.686733
# 2025-02-27  2.826086  2.754614  2.734471  2.724533
# 2025-02-28  2.831850  2.760071  2.740193  2.756300
#
# [517 rows x 4 columns]

# %%
resampled_hourly = axial_tmpsf_sub.resample('h').mean()
rolled_hourly = resampled_hourly.rolling(window=6, center=True).mean()

# %%
resampledaxial.to_csv('/home/jovyan/data/tmpsf/axial_tmpsf.csv')
